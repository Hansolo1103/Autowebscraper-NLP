# %%
#Library Imports
import numpy as np
import pandas as pd
import nltk
import os

# %%
#XLSX file to pandas dataframe

data = pd.read_excel('./Input.xlsx')
df = pd.DataFrame(data)

# %% [markdown]
# CREATION OF A LIST OUT OF THE GIVEN LIST OF POSITIVE AND NEGATIVE
#
# WORDS GIVEN IN THE MASTERDICTIONARY

# %%
positive = []

with open('./MasterDictionary/positive-words.txt', 'r') as pf:
    line = pf.readlines()
    for lin in line:
        k = lin.replace('\n','')
        positive.append(k)

# %%
positive
# Out:
# ['a+',
#  'abound',
#  'abounds',
#  'abundance',
#  'abundant',
#  'accessable',
#  'accessible',
#  'acclaim',
#  'acclaimed',
#  'acclamation',
#  'accolade',
#  'accolades',
#  'accommodative',
#  'accomodative',
#  'accomplish',
#  'accomplished',
#  'accomplishment',
#  'accomplishments',
#  'accurate',
#  'accurately',
#  'achievable',
#  'achievement',
#  'achievements',
#  'achievible',
#  'acumen',
#  'adaptable',
#  'adaptive',
#  'adequate',
#  'adjustable',
#  'admirable',
#  'admirably',
#  'admiration',
#  'admire',
#  'admirer',
#  'admiring',
#  'admiringly',
#  'adorable',
#  'adore',
#  'adored',
#  'adorer',
#  'adoring',
#  'adoringly',
#  'adroit',
#  'adroitly',
#  'adulate',
#  'adulation',
#  'adulatory',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'advantageously',
#  'advantages',
#  'adventuresome',
#  'adventurous',
#  'advocate',
#  'advocated',
#  'advocates',
#  'affability',
#  'affable',
#  'affably',
#  'affectation',
#  'affection',
#  'affectionate',
#  'affinity',
#  'affirm',
#  'affirmation',
#  'affirmative',
#  'affluence',
#  'affluent',
#  'afford',
#  'affordable',
#  'affordably',
#  'afordable',
#  'agile',
#  'agilely',
#  'agility',
#  'agreeable',
#  'agreeableness',
#  'agreeably',
#  'all-around',
#  'alluring',
#  'alluringly',
#  'altruistic',
#  'altruistically',
#  'amaze',
#  'amazed',
#  'amazement',
#  'amazes',
#  'amazing',
#  'amazingly',
#  'ambitious',
#  'ambitiously',
#  'ameliorate',
#  'amenable',
#  'amenity',
#  'amiability',
#  'amiabily',
#  'amiable',
#  'amicability',
#  'amicable',
#  'amicably',
#  'amity',
#  'ample',
#  'amply',
#  'amuse',
#  'amusing',
#  'amusingly',
#  'angel',
#  'angelic',
#  'apotheosis',
#  'appeal',
#  'appealing',
#  'applaud',
#  'appreciable',
#  'appreciate',
#  'appreciated',
#  'appreciates',
#  'appreciative',
#  'appreciatively',
#  'appropriate',
#  'approval',
#  'approve',
#  'ardent',
#  'ardently',
#  'ardor',
#  'articulate',
#  'aspiration',
#  'aspirations',
#  'aspire',
#  'assurance',
#  'assurances',
#  'assure',
#  'assuredly',
#  'assuring',
#  'astonish',
#  'astonished',
#  'astonishing',
#  'astonishingly',
#  'astonishment',
#  'astound',
#  'astounded',
#  'astounding',
#  'astoundingly',
#  'astutely',
#  'attentive',
#  'attraction',
#  'attractive',
#  'attractively',
#  'attune',
#  'audible',
#  'audibly',
#  'auspicious',
#  'authentic',
#  'authoritative',
#  'autonomous',
#  'available',
#  'aver',
#  'avid',
#  'avidly',
#  'award',
#  'awarded',
#  'awards',
#  'awe',
#  'awed',
#  'awesome',
#  'awesomely',
#  'awesomeness',
#  'awestruck',
#  'awsome',
#  'backbone',
#  'balanced',
#  'bargain',
#  'beauteous',
#  'beautiful',
#  'beautifullly',
#  'beautifully',
#  'beautify',
#  'beauty',
#  'beckon',
#  'beckoned',
#  'beckoning',
#  'beckons',
#  'believable',
#  'believeable',
#  'beloved',
#  'benefactor',
#  'beneficent',
#  'beneficial',
#  'beneficially',
#  'beneficiary',
#  'benefit',
#  'benefits',
#  'benevolence',
#  'benevolent',
#  'benifits',
#  'best',
#  'best-known',
#  'best-performing',
#  'best-selling',
#  'better',
#  'better-known',
#  'better-than-expected',
#  'beutifully',
#  'blameless',
#  'bless',
#  'blessing',
#  'bliss',
#  'blissful',
#  'blissfully',
#  'blithe',
#  'blockbuster',
#  'bloom',
#  'blossom',
#  'bolster',
#  'bonny',
#  'bonus',
#  'bonuses',
#  'boom',
#  'booming',
#  'boost',
#  'boundless',
#  'bountiful',
#  'brainiest',
#  'brainy',
#  'brand-new',
#  'brave',
#  'bravery',
#  'bravo',
#  'breakthrough',
#  'breakthroughs',
#  'breathlessness',
#  'breathtaking',
#  'breathtakingly',
#  'breeze',
#  'bright',
#  'brighten',
#  'brighter',
#  'brightest',
#  'brilliance',
#  'brilliances',
#  'brilliant',
#  'brilliantly',
#  'brisk',
#  'brotherly',
#  'bullish',
#  'buoyant',
#  'cajole',
#  'calm',
#  'calming',
#  'calmness',
#  'capability',
#  'capable',
#  'capably',
#  'captivate',
#  'captivating',
#  'carefree',
#  'cashback',
#  'cashbacks',
#  'catchy',
#  'celebrate',
#  'celebrated',
#  'celebration',
#  'celebratory',
#  'champ',
#  'champion',
#  'charisma',
#  'charismatic',
#  'charitable',
#  'charm',
#  'charming',
#  'charmingly',
#  'chaste',
#  'cheaper',
#  'cheapest',
#  'cheer',
#  'cheerful',
#  'cheery',
#  'cherish',
#  'cherished',
#  'cherub',
#  'chic',
#  'chivalrous',
#  'chivalry',
#  'civility',
#  'civilize',
#  'clarity',
#  'classic',
#  'classy',
#  'clean',
#  'cleaner',
#  'cleanest',
#  'cleanliness',
#  'cleanly',
#  'clear',
#  'clear-cut',
#  'cleared',
#  'clearer',
#  'clearly',
#  'clears',
#  'clever',
#  'cleverly',
#  'cohere',
#  'coherence',
#  'coherent',
#  'cohesive',
#  'colorful',
#  'comely',
#  'comfort',
#  'comfortable',
#  'comfortably',
#  'comforting',
#  'comfy',
#  'commend',
#  'commendable',
#  'commendably',
#  'commitment',
#  'commodious',
#  'compact',
#  'compactly',
#  'compassion',
#  'compassionate',
#  'compatible',
#  'competitive',
#  'complement',
#  'complementary',
#  'complemented',
#  'complements',
#  'compliant',
#  'compliment',
#  'complimentary',
#  'comprehensive',
#  'conciliate',
#  'conciliatory',
#  'concise',
#  'confidence',
#  'confident',
#  'congenial',
#  'congratulate',
#  'congratulation',
#  'congratulations',
#  'congratulatory',
#  'conscientious',
#  'considerate',
#  'consistent',
#  'consistently',
#  'constructive',
#  'consummate',
#  'contentment',
#  'continuity',
#  'contrasty',
#  'contribution',
#  'convenience',
#  'convenient',
#  'conveniently',
#  'convience',
#  'convienient',
#  'convient',
#  'convincing',
#  'convincingly',
#  'cool',
#  'coolest',
#  'cooperative',
#  'cooperatively',
#  'cornerstone',
#  'correct',
#  'correctly',
#  'cost-effective',
#  'cost-saving',
#  'counter-attack',
#  'counter-attacks',
#  'courage',
#  'courageous',
#  'courageously',
#  'courageousness',
#  'courteous',
#  'courtly',
#  'covenant',
#  'cozy',
#  'creative',
#  'credence',
#  'credible',
#  'crisp',
#  'crisper',
#  'cure',
#  'cure-all',
#  'cushy',
#  'cute',
#  'cuteness',
#  'danke',
#  'danken',
#  'daring',
#  'daringly',
#  'darling',
#  'dashing',
#  'dauntless',
#  'dawn',
#  'dazzle',
#  'dazzled',
#  'dazzling',
#  'dead-cheap',
#  'dead-on',
#  'decency',
#  'decent',
#  'decisive',
#  'decisiveness',
#  'dedicated',
#  'defeat',
#  'defeated',
#  'defeating',
#  'defeats',
#  'defender',
#  'deference',
#  'deft',
#  'deginified',
#  'delectable',
#  'delicacy',
#  'delicate',
#  'delicious',
#  'delight',
#  'delighted',
#  'delightful',
#  'delightfully',
#  'delightfulness',
#  'dependable',
#  'dependably',
#  'deservedly',
#  'deserving',
#  'desirable',
#  'desiring',
#  'desirous',
#  'destiny',
#  'detachable',
#  'devout',
#  'dexterous',
#  'dexterously',
#  'dextrous',
#  'dignified',
#  'dignify',
#  'dignity',
#  'diligence',
#  'diligent',
#  'diligently',
#  'diplomatic',
#  'dirt-cheap',
#  'distinction',
#  'distinctive',
#  'distinguished',
#  'diversified',
#  'divine',
#  'divinely',
#  'dominate',
#  'dominated',
#  'dominates',
#  'dote',
#  'dotingly',
#  'doubtless',
#  'dreamland',
#  'dumbfounded',
#  'dumbfounding',
#  'dummy-proof',
#  'durable',
#  'dynamic',
#  'eager',
#  'eagerly',
#  'eagerness',
#  'earnest',
#  'earnestly',
#  'earnestness',
#  'ease',
#  'eased',
#  'eases',
#  'easier',
#  'easiest',
#  'easiness',
#  'easing',
#  'easy',
#  'easy-to-use',
#  'easygoing',
#  'ebullience',
#  'ebullient',
#  'ebulliently',
#  'ecenomical',
#  'economical',
#  'ecstasies',
#  'ecstasy',
#  'ecstatic',
#  'ecstatically',
#  'edify',
#  'educated',
#  'effective',
#  'effectively',
#  'effectiveness',
#  'effectual',
#  'efficacious',
#  'efficient',
#  'efficiently',
#  'effortless',
#  'effortlessly',
#  'effusion',
#  'effusive',
#  'effusively',
#  'effusiveness',
#  'elan',
#  'elate',
#  'elated',
#  'elatedly',
#  'elation',
#  'electrify',
#  'elegance',
#  'elegant',
#  'elegantly',
#  'elevate',
#  'elite',
#  'eloquence',
#  'eloquent',
#  'eloquently',
#  'embolden',
#  'eminence',
#  'eminent',
#  'empathize',
#  'empathy',
#  'empower',
#  'empowerment',
#  'enchant',
#  'enchanted',
#  'enchanting',
#  'enchantingly',
#  'encourage',
#  'encouragement',
#  'encouraging',
#  'encouragingly',
#  'endear',
#  'endearing',
#  'endorse',
#  'endorsed',
#  'endorsement',
#  'endorses',
#  'endorsing',
#  'energetic',
#  'energize',
#  'energy-efficient',
#  'energy-saving',
#  'engaging',
#  'engrossing',
#  'enhance',
#  'enhanced',
#  'enhancement',
#  'enhances',
#  'enjoy',
#  'enjoyable',
#  'enjoyably',
#  'enjoyed',
#  'enjoying',
#  'enjoyment',
#  'enjoys',
#  'enlighten',
#  'enlightenment',
#  'enliven',
#  'ennoble',
#  'enough',
#  'enrapt',
#  'enrapture',
#  'enraptured',
#  'enrich',
#  'enrichment',
#  'enterprising',
#  'entertain',
#  'entertaining',
#  'entertains',
#  'enthral',
#  'enthrall',
#  'enthralled',
#  'enthuse',
#  'enthusiasm',
#  'enthusiast',
#  'enthusiastic',
#  'enthusiastically',
#  'entice',
#  'enticed',
#  'enticing',
#  'enticingly',
#  'entranced',
#  'entrancing',
#  'entrust',
#  'enviable',
#  'enviably',
#  'envious',
#  'enviously',
#  'enviousness',
#  'envy',
#  'equitable',
#  'ergonomical',
#  'err-free',
#  'erudite',
#  'ethical',
#  'eulogize',
#  'euphoria',
#  'euphoric',
#  'euphorically',
#  'evaluative',
#  'evenly',
#  'eventful',
#  'everlasting',
#  'evocative',
#  'exalt',
#  'exaltation',
#  'exalted',
#  'exaltedly',
#  'exalting',
#  'exaltingly',
#  'examplar',
#  'examplary',
#  'excallent',
#  'exceed',
#  'exceeded',
#  'exceeding',
#  'exceedingly',
#  'exceeds',
#  'excel',
#  'exceled',
#  'excelent',
#  'excellant',
#  'excelled',
#  'excellence',
#  'excellency',
#  'excellent',
#  'excellently',
#  'excels',
#  'exceptional',
#  'exceptionally',
#  'excite',
#  'excited',
#  'excitedly',
#  'excitedness',
#  'excitement',
#  'excites',
#  'exciting',
#  'excitingly',
#  'exellent',
#  'exemplar',
#  'exemplary',
#  'exhilarate',
#  'exhilarating',
#  'exhilaratingly',
#  'exhilaration',
#  'exonerate',
#  'expansive',
#  'expeditiously',
#  'expertly',
#  'exquisite',
#  'exquisitely',
#  'extol',
#  'extoll',
#  'extraordinarily',
#  'extraordinary',
#  'exuberance',
#  'exuberant',
#  'exuberantly',
#  'exult',
#  'exultant',
#  'exultation',
#  'exultingly',
#  'eye-catch',
#  'eye-catching',
#  'eyecatch',
#  'eyecatching',
#  'fabulous',
#  'fabulously',
#  'facilitate',
#  'fair',
#  'fairly',
#  'fairness',
#  'faith',
#  'faithful',
#  'faithfully',
#  'faithfulness',
#  'fame',
#  'famed',
#  'famous',
#  'famously',
#  'fancier',
#  'fancinating',
#  'fancy',
#  'fanfare',
#  'fans',
#  'fantastic',
#  'fantastically',
#  'fascinate',
#  'fascinating',
#  'fascinatingly',
#  'fascination',
#  'fashionable',
#  'fashionably',
#  'fast',
#  'fast-growing',
#  'fast-paced',
#  'faster',
#  'fastest',
#  'fastest-growing',
#  'faultless',
#  'fav',
#  'fave',
#  'favor',
#  'favorable',
#  'favored',
#  'favorite',
#  'favorited',
#  'favour',
#  'fearless',
#  'fearlessly',
#  'feasible',
#  'feasibly',
#  'feat',
#  'feature-rich',
#  'fecilitous',
#  'feisty',
#  'felicitate',
#  'felicitous',
#  'felicity',
#  'fertile',
#  'fervent',
#  'fervently',
#  'fervid',
#  'fervidly',
#  'fervor',
#  'festive',
#  'fidelity',
#  'fiery',
#  'fine',
#  'fine-looking',
#  'finely',
#  'finer',
#  'finest',
#  'firmer',
#  'first-class',
#  'first-in-class',
#  'first-rate',
#  'flashy',
#  'flatter',
#  'flattering',
#  'flatteringly',
#  'flawless',
#  'flawlessly',
#  'flexibility',
#  'flexible',
#  'flourish',
#  'flourishing',
#  'fluent',
#  'flutter',
#  'fond',
#  'fondly',
#  'fondness',
#  'foolproof',
#  'foremost',
#  'foresight',
#  'formidable',
#  'fortitude',
#  'fortuitous',
#  'fortuitously',
#  'fortunate',
#  'fortunately',
#  'fortune',
#  'fragrant',
#  'free',
#  'freed',
#  'freedom',
#  'freedoms',
#  'fresh',
#  'fresher',
#  'freshest',
#  'friendliness',
#  'friendly',
#  'frolic',
#  'frugal',
#  'fruitful',
#  'ftw',
#  'fulfillment',
#  'fun',
#  'futurestic',
#  'futuristic',
#  'gaiety',
#  'gaily',
#  'gain',
#  'gained',
#  'gainful',
#  'gainfully',
#  'gaining',
#  'gains',
#  'gallant',
#  'gallantly',
#  'galore',
#  'geekier',
#  'geeky',
#  'gem',
#  'gems',
#  'generosity',
#  'generous',
#  'generously',
#  'genial',
#  'genius',
#  'gentle',
#  'gentlest',
#  'genuine',
#  'gifted',
#  'glad',
#  'gladden',
#  'gladly',
#  'gladness',
#  'glamorous',
#  'glee',
#  'gleeful',
#  'gleefully',
#  'glimmer',
#  'glimmering',
#  'glisten',
#  'glistening',
#  'glitter',
#  'glitz',
#  'glorify',
#  'glorious',
#  'gloriously',
#  'glory',
#  'glow',
#  'glowing',
#  'glowingly',
#  'god-given',
#  'god-send',
#  'godlike',
#  'godsend',
#  'gold',
#  'golden',
#  'good',
#  'goodly',
#  'goodness',
#  'goodwill',
#  'goood',
#  'gooood',
#  'gorgeous',
#  'gorgeously',
#  'grace',
#  'graceful',
#  'gracefully',
#  'gracious',
#  'graciously',
#  'graciousness',
#  'grand',
#  'grandeur',
#  'grateful',
#  'gratefully',
#  'gratification',
#  'gratified',
#  'gratifies',
#  'gratify',
#  'gratifying',
#  'gratifyingly',
#  'gratitude',
#  'great',
#  'greatest',
#  'greatness',
#  'grin',
#  'groundbreaking',
#  'guarantee',
#  'guidance',
#  'guiltless',
#  'gumption',
#  'gush',
#  'gusto',
#  'gutsy',
#  'hail',
#  'halcyon',
#  'hale',
#  'hallmark',
#  'hallmarks',
#  'hallowed',
#  'handier',
#  'handily',
#  'hands-down',
#  'handsome',
#  'handsomely',
#  'handy',
#  'happier',
#  'happily',
#  'happiness',
#  'happy',
#  'hard-working',
#  'hardier',
#  'hardy',
#  'harmless',
#  'harmonious',
#  'harmoniously',
#  'harmonize',
#  'harmony',
#  'headway',
#  'heal',
#  'healthful',
#  'healthy',
#  'hearten',
#  'heartening',
#  'heartfelt',
#  'heartily',
#  'heartwarming',
#  'heaven',
#  'heavenly',
#  'helped',
#  'helpful',
#  'helping',
#  'hero',
#  'heroic',
#  'heroically',
#  'heroine',
#  'heroize',
#  'heros',
#  'high-quality',
#  'high-spirited',
#  'hilarious',
#  'holy',
#  'homage',
#  'honest',
#  'honesty',
#  'honor',
#  'honorable',
#  'honored',
#  'honoring',
#  'hooray',
#  'hopeful',
#  'hospitable',
#  'hot',
#  'hotcake',
#  'hotcakes',
#  'hottest',
#  'hug',
#  'humane',
#  'humble',
#  'humility',
#  'humor',
#  'humorous',
#  'humorously',
#  'humour',
#  'humourous',
#  'ideal',
#  'idealize',
#  'ideally',
#  'idol',
#  'idolize',
#  'idolized',
#  'idyllic',
#  'illuminate',
#  'illuminati',
#  'illuminating',
#  'illumine',
#  'illustrious',
#  'ilu',
#  'imaculate',
#  'imaginative',
#  'immaculate',
#  'immaculately',
#  'immense',
#  'impartial',
#  'impartiality',
#  'impartially',
#  'impassioned',
#  'impeccable',
#  'impeccably',
#  'important',
#  'impress',
#  'impressed',
#  'impresses',
#  'impressive',
#  'impressively',
#  'impressiveness',
#  'improve',
#  'improved',
#  'improvement',
#  'improvements',
#  'improves',
#  'improving',
#  'incredible',
#  'incredibly',
#  'indebted',
#  'individualized',
#  'indulgence',
#  'indulgent',
#  'industrious',
#  'inestimable',
#  'inestimably',
#  'inexpensive',
#  'infallibility',
#  'infallible',
#  'infallibly',
#  'influential',
#  'ingenious',
#  'ingeniously',
#  'ingenuity',
#  'ingenuous',
#  'ingenuously',
#  'innocuous',
#  'innovation',
#  'innovative',
#  'inpressed',
#  'insightful',
#  ...]

# %%
negative = []

with open('./MasterDictionary/negative-words.txt', 'r') as pf:
    line = pf.readlines()
    for lin in line:
        k = lin.replace('\n','')
        negative.append(k)

# %%
negative
# Out:
# ['two-faced',
#  'two-faces',
#  'abnormal',
#  'abolish',
#  'abominable',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abort',
#  'aborted',
#  'aborts',
#  'abrade',
#  'abrasive',
#  'abrupt',
#  'abruptly',
#  'abscond',
#  'absence',
#  'absent-minded',
#  'absentee',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusive',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'accidental',
#  'accost',
#  'accursed',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accuses',
#  'accusing',
#  'accusingly',
#  'acerbate',
#  'acerbic',
#  'acerbically',
#  'ache',
#  'ached',
#  'aches',
#  'achey',
#  'aching',
#  'acrid',
#  'acridly',
#  'acridness',
#  'acrimonious',
#  'acrimoniously',
#  'acrimony',
#  'adamant',
#  'adamantly',
#  'addict',
#  'addicted',
#  'addicting',
#  'addicts',
#  'admonish',
#  'admonisher',
#  'admonishingly',
#  'admonishment',
#  'admonition',
#  'adulterate',
#  'adulterated',
#  'adulteration',
#  'adulterier',
#  'adversarial',
#  'adversary',
#  'adverse',
#  'adversity',
#  'afflict',
#  'affliction',
#  'afflictive',
#  'affront',
#  'afraid',
#  'aggravate',
#  'aggravating',
#  'aggravation',
#  'aggression',
#  'aggressive',
#  'aggressiveness',
#  'aggressor',
#  'aggrieve',
#  'aggrieved',
#  'aggrivation',
#  'aghast',
#  'agonies',
#  'agonize',
#  'agonizing',
#  'agonizingly',
#  'agony',
#  'aground',
#  'ail',
#  'ailing',
#  'ailment',
#  'aimless',
#  'alarm',
#  'alarmed',
#  'alarming',
#  'alarmingly',
#  'alienate',
#  'alienated',
#  'alienation',
#  'allegation',
#  'allegations',
#  'allege',
#  'allergic',
#  'allergies',
#  'allergy',
#  'aloof',
#  'altercation',
#  'ambiguity',
#  'ambiguous',
#  'ambivalence',
#  'ambivalent',
#  'ambush',
#  'amiss',
#  'amputate',
#  'anarchism',
#  'anarchist',
#  'anarchistic',
#  'anarchy',
#  'anemic',
#  'anger',
#  'angrily',
#  'angriness',
#  'angry',
#  'anguish',
#  'animosity',
#  'annihilate',
#  'annihilation',
#  'annoy',
#  'annoyance',
#  'annoyances',
#  'annoyed',
#  'annoying',
#  'annoyingly',
#  'annoys',
#  'anomalous',
#  'anomaly',
#  'antagonism',
#  'antagonist',
#  'antagonistic',
#  'antagonize',
#  'anti-',
#  'anti-american',
#  'anti-israeli',
#  'anti-occupation',
#  'anti-proliferation',
#  'anti-semites',
#  'anti-social',
#  'anti-us',
#  'anti-white',
#  'antipathy',
#  'antiquated',
#  'antithetical',
#  'anxieties',
#  'anxiety',
#  'anxious',
#  'anxiously',
#  'anxiousness',
#  'apathetic',
#  'apathetically',
#  'apathy',
#  'apocalypse',
#  'apocalyptic',
#  'apologist',
#  'apologists',
#  'appal',
#  'appall',
#  'appalled',
#  'appalling',
#  'appallingly',
#  'apprehension',
#  'apprehensions',
#  'apprehensive',
#  'apprehensively',
#  'arbitrary',
#  'arcane',
#  'archaic',
#  'arduous',
#  'arduously',
#  'argumentative',
#  'arrogance',
#  'arrogant',
#  'arrogantly',
#  'ashamed',
#  'asinine',
#  'asininely',
#  'asinininity',
#  'askance',
#  'asperse',
#  'aspersion',
#  'aspersions',
#  'assail',
#  'assassin',
#  'assassinate',
#  'assault',
#  'assult',
#  'astray',
#  'asunder',
#  'atrocious',
#  'atrocities',
#  'atrocity',
#  'atrophy',
#  'attack',
#  'attacks',
#  'audacious',
#  'audaciously',
#  'audaciousness',
#  'audacity',
#  'audiciously',
#  'austere',
#  'authoritarian',
#  'autocrat',
#  'autocratic',
#  'avalanche',
#  'avarice',
#  'avaricious',
#  'avariciously',
#  'avenge',
#  'averse',
#  'aversion',
#  'aweful',
#  'awful',
#  'awfully',
#  'awfulness',
#  'awkward',
#  'awkwardness',
#  'ax',
#  'babble',
#  'back-logged',
#  'back-wood',
#  'back-woods',
#  'backache',
#  'backaches',
#  'backaching',
#  'backbite',
#  'backbiting',
#  'backward',
#  'backwardness',
#  'backwood',
#  'backwoods',
#  'bad',
#  'badly',
#  'baffle',
#  'baffled',
#  'bafflement',
#  'baffling',
#  'bait',
#  'balk',
#  'banal',
#  'banalize',
#  'bane',
#  'banish',
#  'banishment',
#  'bankrupt',
#  'barbarian',
#  'barbaric',
#  'barbarically',
#  'barbarity',
#  'barbarous',
#  'barbarously',
#  'barren',
#  'baseless',
#  'bash',
#  'bashed',
#  'bashful',
#  'bashing',
#  'bastard',
#  'bastards',
#  'battered',
#  'battering',
#  'batty',
#  'bearish',
#  'beastly',
#  'bedlam',
#  'bedlamite',
#  'befoul',
#  'beg',
#  'beggar',
#  'beggarly',
#  'begging',
#  'beguile',
#  'belabor',
#  'belated',
#  'beleaguer',
#  'belie',
#  'belittle',
#  'belittled',
#  'belittling',
#  'bellicose',
#  'belligerence',
#  'belligerent',
#  'belligerently',
#  'bemoan',
#  'bemoaning',
#  'bemused',
#  'bent',
#  'berate',
#  'bereave',
#  'bereavement',
#  'bereft',
#  'berserk',
#  'beseech',
#  'beset',
#  'besiege',
#  'besmirch',
#  'bestial',
#  'betray',
#  'betrayal',
#  'betrayals',
#  'betrayer',
#  'betraying',
#  'betrays',
#  'bewail',
#  'beware',
#  'bewilder',
#  'bewildered',
#  'bewildering',
#  'bewilderingly',
#  'bewilderment',
#  'bewitch',
#  'bias',
#  'biased',
#  'biases',
#  'bicker',
#  'bickering',
#  'bid-rigging',
#  'bigotries',
#  'bigotry',
#  'bitch',
#  'bitchy',
#  'biting',
#  'bitingly',
#  'bitter',
#  'bitterly',
#  'bitterness',
#  'bizarre',
#  'blab',
#  'blabber',
#  'blackmail',
#  'blah',
#  'blame',
#  'blameworthy',
#  'bland',
#  'blandish',
#  'blaspheme',
#  'blasphemous',
#  'blasphemy',
#  'blasted',
#  'blatant',
#  'blatantly',
#  'blather',
#  'bleak',
#  'bleakly',
#  'bleakness',
#  'bleed',
#  'bleeding',
#  'bleeds',
#  'blemish',
#  'blind',
#  'blinding',
#  'blindingly',
#  'blindside',
#  'blister',
#  'blistering',
#  'bloated',
#  'blockage',
#  'blockhead',
#  'bloodshed',
#  'bloodthirsty',
#  'bloody',
#  'blotchy',
#  'blow',
#  'blunder',
#  'blundering',
#  'blunders',
#  'blunt',
#  'blur',
#  'bluring',
#  'blurred',
#  'blurring',
#  'blurry',
#  'blurs',
#  'blurt',
#  'boastful',
#  'boggle',
#  'bogus',
#  'boil',
#  'boiling',
#  'boisterous',
#  'bomb',
#  'bombard',
#  'bombardment',
#  'bombastic',
#  'bondage',
#  'bonkers',
#  'bore',
#  'bored',
#  'boredom',
#  'bores',
#  'boring',
#  'botch',
#  'bother',
#  'bothered',
#  'bothering',
#  'bothers',
#  'bothersome',
#  'bowdlerize',
#  'boycott',
#  'braggart',
#  'bragger',
#  'brainless',
#  'brainwash',
#  'brash',
#  'brashly',
#  'brashness',
#  'brat',
#  'bravado',
#  'brazen',
#  'brazenly',
#  'brazenness',
#  'breach',
#  'break',
#  'break-up',
#  'break-ups',
#  'breakdown',
#  'breaking',
#  'breaks',
#  'breakup',
#  'breakups',
#  'bribery',
#  'brimstone',
#  'bristle',
#  'brittle',
#  'broke',
#  'broken',
#  'broken-hearted',
#  'brood',
#  'browbeat',
#  'bruise',
#  'bruised',
#  'bruises',
#  'bruising',
#  'brusque',
#  'brutal',
#  'brutalising',
#  'brutalities',
#  'brutality',
#  'brutalize',
#  'brutalizing',
#  'brutally',
#  'brute',
#  'brutish',
#  'bs',
#  'buckle',
#  'bug',
#  'bugging',
#  'buggy',
#  'bugs',
#  'bulkier',
#  'bulkiness',
#  'bulky',
#  'bulkyness',
#  'bull****',
#  'bull----',
#  'bullies',
#  'bullshit',
#  'bullshyt',
#  'bully',
#  'bullying',
#  'bullyingly',
#  'bum',
#  'bump',
#  'bumped',
#  'bumping',
#  'bumpping',
#  'bumps',
#  'bumpy',
#  'bungle',
#  'bungler',
#  'bungling',
#  'bunk',
#  'burden',
#  'burdensome',
#  'burdensomely',
#  'burn',
#  'burned',
#  'burning',
#  'burns',
#  'bust',
#  'busts',
#  'busybody',
#  'butcher',
#  'butchery',
#  'buzzing',
#  'byzantine',
#  'cackle',
#  'calamities',
#  'calamitous',
#  'calamitously',
#  'calamity',
#  'callous',
#  'calumniate',
#  'calumniation',
#  'calumnies',
#  'calumnious',
#  'calumniously',
#  'calumny',
#  'cancer',
#  'cancerous',
#  'cannibal',
#  'cannibalize',
#  'capitulate',
#  'capricious',
#  'capriciously',
#  'capriciousness',
#  'capsize',
#  'careless',
#  'carelessness',
#  'caricature',
#  'carnage',
#  'carp',
#  'cartoonish',
#  'cash-strapped',
#  'castigate',
#  'castrated',
#  'casualty',
#  'cataclysm',
#  'cataclysmal',
#  'cataclysmic',
#  'cataclysmically',
#  'catastrophe',
#  'catastrophes',
#  'catastrophic',
#  'catastrophically',
#  'catastrophies',
#  'caustic',
#  'caustically',
#  'cautionary',
#  'cave',
#  'censure',
#  'chafe',
#  'chaff',
#  'chagrin',
#  'challenging',
#  'chaos',
#  'chaotic',
#  'chasten',
#  'chastise',
#  'chastisement',
#  'chatter',
#  'chatterbox',
#  'cheap',
#  'cheapen',
#  'cheaply',
#  'cheat',
#  'cheated',
#  'cheater',
#  'cheating',
#  'cheats',
#  'checkered',
#  'cheerless',
#  'cheesy',
#  'chide',
#  'childish',
#  'chill',
#  'chilly',
#  'chintzy',
#  'choke',
#  'choleric',
#  'choppy',
#  'chore',
#  'chronic',
#  'chunky',
#  'clamor',
#  'clamorous',
#  'clash',
#  'cliche',
#  'cliched',
#  'clique',
#  'clog',
#  'clogged',
#  'clogs',
#  'cloud',
#  'clouding',
#  'cloudy',
#  'clueless',
#  'clumsy',
#  'clunky',
#  'coarse',
#  'cocky',
#  'coerce',
#  'coercion',
#  'coercive',
#  'cold',
#  'coldly',
#  'collapse',
#  'collude',
#  'collusion',
#  'combative',
#  'combust',
#  'comical',
#  'commiserate',
#  'commonplace',
#  'commotion',
#  'commotions',
#  'complacent',
#  'complain',
#  'complained',
#  'complaining',
#  'complains',
#  'complaint',
#  'complaints',
#  'complex',
#  'complicated',
#  'complication',
#  'complicit',
#  'compulsion',
#  'compulsive',
#  'concede',
#  'conceded',
#  'conceit',
#  'conceited',
#  'concen',
#  'concens',
#  'concern',
#  'concerned',
#  'concerns',
#  'concession',
#  'concessions',
#  'condemn',
#  'condemnable',
#  'condemnation',
#  'condemned',
#  'condemns',
#  'condescend',
#  'condescending',
#  'condescendingly',
#  'condescension',
#  'confess',
#  'confession',
#  'confessions',
#  'confined',
#  'conflict',
#  'conflicted',
#  'conflicting',
#  'conflicts',
#  'confound',
#  'confounded',
#  'confounding',
#  'confront',
#  'confrontation',
#  'confrontational',
#  'confuse',
#  'confused',
#  'confuses',
#  'confusing',
#  'confusion',
#  'confusions',
#  'congested',
#  'congestion',
#  'cons',
#  'conscons',
#  'conservative',
#  'conspicuous',
#  'conspicuously',
#  'conspiracies',
#  'conspiracy',
#  'conspirator',
#  'conspiratorial',
#  'conspire',
#  'consternation',
#  'contagious',
#  'contaminate',
#  'contaminated',
#  'contaminates',
#  'contaminating',
#  'contamination',
#  'contempt',
#  'contemptible',
#  'contemptuous',
#  'contemptuously',
#  'contend',
#  'contention',
#  'contentious',
#  'contort',
#  'contortions',
#  'contradict',
#  'contradiction',
#  'contradictory',
#  'contrariness',
#  'contravene',
#  'contrive',
#  'contrived',
#  'controversial',
#  'controversy',
#  'convoluted',
#  'corrode',
#  'corrosion',
#  'corrosions',
#  'corrosive',
#  'corrupt',
#  'corrupted',
#  'corrupting',
#  'corruption',
#  'corrupts',
#  'corruptted',
#  'costlier',
#  'costly',
#  'counter-productive',
#  'counterproductive',
#  'coupists',
#  'covetous',
#  'coward',
#  'cowardly',
#  'crabby',
#  'crack',
#  'cracked',
#  'cracks',
#  'craftily',
#  'craftly',
#  'crafty',
#  'cramp',
#  'cramped',
#  'cramping',
#  'cranky',
#  'crap',
#  'crappy',
#  'craps',
#  'crash',
#  'crashed',
#  'crashes',
#  'crashing',
#  'crass',
#  'craven',
#  'cravenly',
#  'craze',
#  'crazily',
#  'craziness',
#  'crazy',
#  'creak',
#  'creaking',
#  'creaks',
#  'credulous',
#  'creep',
#  'creeping',
#  'creeps',
#  'creepy',
#  'crept',
#  'crime',
#  'criminal',
#  'cringe',
#  'cringed',
#  'cringes',
#  'cripple',
#  'crippled',
#  'cripples',
#  'crippling',
#  'crisis',
#  'critic',
#  'critical',
#  'criticism',
#  'criticisms',
#  'criticize',
#  'criticized',
#  'criticizing',
#  'critics',
#  'cronyism',
#  'crook',
#  'crooked',
#  'crooks',
#  'crowded',
#  'crowdedness',
#  'crude',
#  'cruel',
#  'crueler',
#  'cruelest',
#  'cruelly',
#  'cruelness',
#  'cruelties',
#  'cruelty',
#  'crumble',
#  'crumbling',
#  'crummy',
#  'crumple',
#  'crumpled',
#  'crumples',
#  'crush',
#  'crushed',
#  'crushing',
#  'cry',
#  'culpable',
#  'culprit',
#  'cumbersome',
#  'cunt',
#  'cunts',
#  'cuplrit',
#  'curse',
#  'cursed',
#  'curses',
#  'curt',
#  'cuss',
#  'cussed',
#  'cutthroat',
#  'cynical',
#  'cynicism',
#  'd*mn',
#  'damage',
#  'damaged',
#  'damages',
#  'damaging',
#  'damn',
#  'damnable',
#  'damnably',
#  'damnation',
#  'damned',
#  'damning',
#  'damper',
#  'danger',
#  'dangerous',
#  'dangerousness',
#  'dark',
#  'darken',
#  'darkened',
#  'darker',
#  'darkness',
#  'dastard',
#  'dastardly',
#  'daunt',
#  'daunting',
#  'dauntingly',
#  'dawdle',
#  'daze',
#  'dazed',
#  'dead',
#  'deadbeat',
#  'deadlock',
#  'deadly',
#  'deadweight',
#  'deaf',
#  'dearth',
#  'death',
#  'debacle',
#  'debase',
#  'debasement',
#  'debaser',
#  'debatable',
#  'debauch',
#  'debaucher',
#  'debauchery',
#  'debilitate',
#  'debilitating',
#  'debility',
#  'debt',
#  'debts',
#  'decadence',
#  'decadent',
#  'decay',
#  'decayed',
#  'deceit',
#  'deceitful',
#  'deceitfully',
#  'deceitfulness',
#  'deceive',
#  'deceiver',
#  'deceivers',
#  'deceiving',
#  'deception',
#  'deceptive',
#  'deceptively',
#  'declaim',
#  'decline',
#  'declines',
#  'declining',
#  'decrement',
#  'decrepit',
#  'decrepitude',
#  'decry',
#  'defamation',
#  'defamations',
#  'defamatory',
#  'defame',
#  'defect',
#  'defective',
#  'defects',
#  'defensive',
#  'defiance',
#  'defiant',
#  'defiantly',
#  'deficiencies',
#  'deficiency',
#  'deficient',
#  'defile',
#  'defiler',
#  'deform',
#  'deformed',
#  'defrauding',
#  'defunct',
#  'defy',
#  'degenerate',
#  'degenerately',
#  'degeneration',
#  'degradation',
#  'degrade',
#  'degrading',
#  'degradingly',
#  'dehumanization',
#  'dehumanize',
#  'deign',
#  'deject',
#  'dejected',
#  'dejectedly',
#  'dejection',
#  'delay',
#  'delayed',
#  'delaying',
#  'delays',
#  'delinquency',
#  'delinquent',
#  'delirious',
#  'delirium',
#  'delude',
#  'deluded',
#  'deluge',
#  'delusion',
#  'delusional',
#  'delusions',
#  'demean',
#  'demeaning',
#  'demise',
#  'demolish',
#  'demolisher',
#  'demon',
#  'demonic',
#  'demonize',
#  'demonized',
#  'demonizes',
#  'demonizing',
#  'demoralize',
#  'demoralizing',
#  'demoralizingly',
#  'denial',
#  'denied',
#  'denies',
#  'denigrate',
#  'denounce',
#  'dense',
#  'dent',
#  'dented',
#  'dents',
#  'denunciate',
#  'denunciation',
#  'denunciations',
#  'deny',
#  'denying',
#  'deplete',
#  'deplorable',
#  'deplorably',
#  'deplore',
#  'deploring',
#  'deploringly',
#  'deprave',
#  'depraved',
#  'depravedly',
#  'deprecate',
#  'depress',
#  'depressed',
#  'depressing',
#  'depressingly',
#  'depression',
#  'depressions',
#  'deprive',
#  'deprived',
#  'deride',
#  'derision',
#  'derisive',
#  'derisively',
#  'derisiveness',
#  'derogatory',
#  'desecrate',
#  'desert',
#  'desertion',
#  'desiccate',
#  'desiccated',
#  'desititute',
#  'desolate',
#  'desolately',
#  'desolation',
#  'despair',
#  'despairing',
#  'despairingly',
#  'desperate',
#  'desperately',
#  'desperation',
#  'despicable',
#  'despicably',
#  ...]

# %%
main_dir = './StopWords/'
stopw_list = []
for file in os.listdir('./StopWords/'):
    
    with open(os.path.join(main_dir, file), 'rb') as f:
        
        line = f.readlines()
        stopw_list.append(line)

# %%
stopw_list
# Out:
# [[b'ERNST\r\n',
#   b'YOUNG\r\n',
#   b'DELOITTE\r\n',
#   b'TOUCHE\r\n',
#   b'KPMG\r\n',
#   b'PRICEWATERHOUSECOOPERS\r\n',
#   b'PRICEWATERHOUSE\r\n',
#   b'COOPERS\r\n'],
#  [b'AFGHANI  | Afghanistan \r\n',
#   b'ARIARY | Madagascar \r\n',
#   b'BAHT | Thailand \r\n',
#   b'BALBOA | Panama \r\n',
#   b'BIRR | Ethiopia \r\n',
#   b'BOLIVAR | Venezuela \r\n',
#   b'BOLIVIANO  | Bolivia \r\n',
#   b'CEDI | Ghana \r\n',
#   b'COLON  | Costa Rica \r\n',
#   b'C\xd3RDOBA  | Nicaragua \r\n',
#   b'DALASI | Gambia \r\n',
#   b'DENAR | Macedonia (Former Yug. Rep.) \r\n',
#   b'DINAR | Algeria \r\n',
#   b'DIRHAM  | Morocco \r\n',
#   b'DOBRA | S\xe3o Tom and Pr\xedncipe \r\n',
#   b'DONG | Vietnam \r\n',
#   b'DRAM | Armenia \r\n',
#   b'ESCUDO  | Cape Verde \r\n',
#   b'EURO  | Belgium \r\n',
#   b'FLORIN | Aruba \r\n',
#   b'FORINT | Hungary \r\n',
#   b'GOURDE | Haiti \r\n',
#   b'GUARANI | Paraguay \r\n',
#   b'GULDEN | Netherlands Antilles \r\n',
#   b'HRYVNIA  | Ukraine \r\n',
#   b'KINA | Papua New Guinea \r\n',
#   b'KIP | Laos \r\n',
#   b'KONVERTIBILNA MARKA  | Bosnia-Herzegovina \r\n',
#   b'KORUNA  | Czech Republic \r\n',
#   b'KRONA | Sweden \r\n',
#   b'KRONE | Denmark \r\n',
#   b'KROON | Estonia \r\n',
#   b'KUNA | Croatia \r\n',
#   b'KWACHA | Zambia \r\n',
#   b'KWANZA | Angola \r\n',
#   b'KYAT | Myanmar \r\n',
#   b'LARI | Georgia \r\n',
#   b'LATS | Latvia \r\n',
#   b'LEK | Albania \r\n',
#   b'LEMPIRA | Honduras \r\n',
#   b'LEONE | Sierra Leone \r\n',
#   b'LEU | Romania \r\n',
#   b'LEV | Bulgaria \r\n',
#   b'LILANGENI  | Swaziland \r\n',
#   b'LIRA | Lebanon \r\n',
#   b'LITAS | Lithuania \r\n',
#   b'LOTI | Lesotho \r\n',
#   b'MANAT | Azerbaijan \r\n',
#   b'METICAL | Mozambique \r\n',
#   b'NAIRA | Nigeria \r\n',
#   b'NAKFA | Eritrea \r\n',
#   b'NEW LIRA | Turkey \r\n',
#   b'NEW SHEQEL  | Israel \r\n',
#   b'NGULTRUM  | Bhutan \r\n',
#   b'NUEVO SOL | Peru \r\n',
#   b'OUGUIYA  | Mauritania \r\n',
#   b'PATACA | Macau \r\n',
#   b'PESO  | Mexico \r\n',
#   b'POUND  | Egypt \r\n',
#   b'PULA  | Botswana \r\n',
#   b'QUETZAL | Guatemala \r\n',
#   b'RAND | South Africa \r\n',
#   b'REAL  | Brazil \r\n',
#   b'RENMINBI  | China \r\n',
#   b'RIAL | Iran \r\n',
#   b'RIEL | Cambodia \r\n',
#   b'RINGGIT | Malaysia \r\n',
#   b'RIYAL | Saudi Arabia \r\n',
#   b'RUBLE | Russia \r\n',
#   b'RUFIYAA | Maldives \r\n',
#   b'RUPEE  | India \r\n',
#   b'RUPEE  | Pakistan \r\n',
#   b'RUPIAH  | Indonesia \r\n',
#   b'SHILLING  | Uganda \r\n',
#   b'SOM | Uzbekistan \r\n',
#   b'SOMONI  | Tajikistan \r\n',
#   b'SPECIAL DRAWING RIGHTS  | International Monetary Fund \r\n',
#   b'TAKA | Bangladesh \r\n',
#   b'TALA | Western Samoa \r\n',
#   b'TENGE | Kazakhstan \r\n',
#   b'TUGRIK  | Mongolia \r\n',
#   b'VATU | Vanuatu \r\n',
#   b'WON  | Korea, South \r\n',
#   b'YEN | Japan \r\n',
#   b'ZLOTY | Poland \r\n'],
#  [b'HUNDRED  | Denominations\r\n',
#   b'THOUSAND\r\n',
#   b'MILLION\r\n',
#   b'BILLION\r\n',
#   b'TRILLION\r\n',
#   b'DATE  | Time related\r\n',
#   b'ANNUAL\r\n',
#   b'ANNUALLY\r\n',
#   b'ANNUM\r\n',
#   b'YEAR\r\n',
#   b'YEARLY\r\n',
#   b'QUARTER\r\n',
#   b'QUARTERLY\r\n',
#   b'QTR\r\n',
#   b'MONTH\r\n',
#   b'MONTHLY\r\n',
#   b'WEEK\r\n',
#   b'WEEKLY\r\n',
#   b'DAY\r\n',
#   b'DAILY\r\n',
#   b'JANUARY  | Calendar\r\n',
#   b'FEBRUARY\r\n',
#   b'MARCH\r\n',
#   b'APRIL\r\n',
#   b'MAY\r\n',
#   b'JUNE\r\n',
#   b'JULY\r\n',
#   b'AUGUST\r\n',
#   b'SEPTEMBER\r\n',
#   b'OCTOBER\r\n',
#   b'NOVEMBER\r\n',
#   b'DECEMBER\r\n',
#   b'JAN\r\n',
#   b'FEB\r\n',
#   b'MAR\r\n',
#   b'APR\r\n',
#   b'MAY\r\n',
#   b'JUN\r\n',
#   b'JUL\r\n',
#   b'AUG\r\n',
#   b'SEP\r\n',
#   b'SEPT\r\n',
#   b'OCT\r\n',
#   b'NOV\r\n',
#   b'DEC\r\n',
#   b'MONDAY\r\n',
#   b'TUESDAY\r\n',
#   b'WEDNESDAY\r\n',
#   b'THURSDAY\r\n',
#   b'FRIDAY\r\n',
#   b'SATURDAY\r\n',
#   b'SUNDAY\r\n',
#   b'ONE  | Numbers\r\n',
#   b'TWO\r\n',
#   b'THREE\r\n',
#   b'FOUR\r\n',
#   b'FIVE\r\n',
#   b'SIX\r\n',
#   b'SEVEN\r\n',
#   b'EIGHT\r\n',
#   b'NINE\r\n',
#   b'TEN\r\n',
#   b'ELEVEN\r\n',
#   b'TWELVE\r\n',
#   b'THIRTEEN\r\n',
#   b'FOURTEEN\r\n',
#   b'FIFTEEN\r\n',
#   b'SIXTEEN\r\n',
#   b'SEVENTEEN\r\n',
#   b'EIGHTEEN\r\n',
#   b'NINETEEN\r\n',
#   b'TWENTY\r\n',
#   b'THIRTY\r\n',
#   b'FORTY\r\n',
#   b'FIFTY\r\n',
#   b'SIXTY\r\n',
#   b'SEVENTY\r\n',
#   b'EIGHTY\r\n',
#   b'NINETY\r\n',
#   b'FIRST\r\n',
#   b'SECOND\r\n',
#   b'THIRD\r\n',
#   b'FOURTH\r\n',
#   b'FIFTH\r\n',
#   b'SIXTH\r\n',
#   b'SEVENTH\r\n',
#   b'EIGHTH\r\n',
#   b'NINTH\r\n',
#   b'TENTH\r\n',
#   b'I  | Roman numerals\r\n',
#   b'II\r\n',
#   b'III\r\n',
#   b'IV\r\n',
#   b'V\r\n',
#   b'VI\r\n',
#   b'VII\r\n',
#   b'VIII\r\n',
#   b'IX\r\n',
#   b'X\r\n',
#   b'XI\r\n',
#   b'XII\r\n',
#   b'XIII\r\n',
#   b'XIV\r\n',
#   b'XV\r\n',
#   b'XVI\r\n',
#   b'XVII\r\n',
#   b'XVIII\r\n',
#   b'XIX\r\n',
#   b'XX'],
#  [b'ABOUT\r\n',
#   b'ABOVE\r\n',
#   b'AFTER\r\n',
#   b'AGAIN\r\n',
#   b'ALL\r\n',
#   b'AM\r\n',
#   b'AMONG\r\n',
#   b'AN\r\n',
#   b'AND\r\n',
#   b'ANY\r\n',
#   b'ARE\r\n',
#   b'AS\r\n',
#   b'AT\r\n',
#   b'BE\r\n',
#   b'BECAUSE\r\n',
#   b'BEEN\r\n',
#   b'BEFORE\r\n',
#   b'BEING\r\n',
#   b'BELOW\r\n',
#   b'BETWEEN\r\n',
#   b'BOTH\r\n',
#   b'BUT\r\n',
#   b'BY\r\n',
#   b'CAN\r\n',
#   b'DID\r\n',
#   b'DO\r\n',
#   b'DOES\r\n',
#   b'DOING\r\n',
#   b'DOWN\r\n',
#   b'DURING\r\n',
#   b'EACH\r\n',
#   b'FEW\r\n',
#   b'FOR\r\n',
#   b'FROM\r\n',
#   b'FURTHER\r\n',
#   b'HAD\r\n',
#   b'HAS\r\n',
#   b'HAVE\r\n',
#   b'HAVING\r\n',
#   b'HE\r\n',
#   b'HER\r\n',
#   b'HERE\r\n',
#   b'HERS\r\n',
#   b'HERSELF\r\n',
#   b'HIM\r\n',
#   b'HIMSELF\r\n',
#   b'HIS\r\n',
#   b'HOW\r\n',
#   b'IF\r\n',
#   b'IN\r\n',
#   b'INTO\r\n',
#   b'IS\r\n',
#   b'IT\r\n',
#   b'ITS\r\n',
#   b'ITSELF\r\n',
#   b'JUST\r\n',
#   b'ME\r\n',
#   b'MORE\r\n',
#   b'MOST\r\n',
#   b'MY\r\n',
#   b'MYSELF\r\n',
#   b'NO\r\n',
#   b'NOR\r\n',
#   b'NOT\r\n',
#   b'NOW\r\n',
#   b'OF\r\n',
#   b'OFF\r\n',
#   b'ON\r\n',
#   b'ONCE\r\n',
#   b'ONLY\r\n',
#   b'OR\r\n',
#   b'OTHER\r\n',
#   b'OUR\r\n',
#   b'OURS\r\n',
#   b'OURSELVES\r\n',
#   b'OUT\r\n',
#   b'OVER\r\n',
#   b'OWN\r\n',
#   b'SAME\r\n',
#   b'SHE\r\n',
#   b'SHOULD\r\n',
#   b'SO\r\n',
#   b'SOME\r\n',
#   b'SUCH\r\n',
#   b'THAN\r\n',
#   b'THAT\r\n',
#   b'THE\r\n',
#   b'THEIR\r\n',
#   b'THEIRS\r\n',
#   b'THEM\r\n',
#   b'THEMSELVES\r\n',
#   b'THEN\r\n',
#   b'THERE\r\n',
#   b'THESE\r\n',
#   b'THEY\r\n',
#   b'THIS\r\n',
#   b'THOSE\r\n',
#   b'THROUGH\r\n',
#   b'TO\r\n',
#   b'TOO\r\n',
#   b'UNDER\r\n',
#   b'UNTIL\r\n',
#   b'UP\r\n',
#   b'VERY\r\n',
#   b'WAS\r\n',
#   b'WE\r\n',
#   b'WERE\r\n',
#   b'WHAT\r\n',
#   b'WHEN\r\n',
#   b'WHERE\r\n',
#   b'WHICH\r\n',
#   b'WHILE\r\n',
#   b'WHO\r\n',
#   b'WHOM\r\n',
#   b'WHY\r\n',
#   b'WITH\r\n',
#   b'YOU\r\n',
#   b'YOUR\r\n',
#   b'YOURS\r\n',
#   b'YOURSELF\r\n',
#   b'YOURSELVES'],
#  [b'a\r\n',
#   b"a's\r\n",
#   b'able\r\n',
#   b'about\r\n',
#   b'above\r\n',
#   b'according\r\n',
#   b'accordingly\r\n',
#   b'across\r\n',
#   b'actually\r\n',
#   b'after\r\n',
#   b'afterwards\r\n',
#   b'again\r\n',
#   b'against\r\n',
#   b"ain't\r\n",
#   b'all\r\n',
#   b'allow\r\n',
#   b'allows\r\n',
#   b'almost\r\n',
#   b'alone\r\n',
#   b'along\r\n',
#   b'already\r\n',
#   b'also\r\n',
#   b'although\r\n',
#   b'always\r\n',
#   b'am\r\n',
#   b'among\r\n',
#   b'amongst\r\n',
#   b'an\r\n',
#   b'and\r\n',
#   b'another\r\n',
#   b'any\r\n',
#   b'anybody\r\n',
#   b'anyhow\r\n',
#   b'anyone\r\n',
#   b'anything\r\n',
#   b'anyway\r\n',
#   b'anyways\r\n',
#   b'anywhere\r\n',
#   b'apart\r\n',
#   b'appear\r\n',
#   b'appreciate\r\n',
#   b'appropriate\r\n',
#   b'are\r\n',
#   b"aren't\r\n",
#   b'around\r\n',
#   b'as\r\n',
#   b'aside\r\n',
#   b'ask\r\n',
#   b'asking\r\n',
#   b'associated\r\n',
#   b'at\r\n',
#   b'available\r\n',
#   b'away\r\n',
#   b'awfully\r\n',
#   b'b\r\n',
#   b'be\r\n',
#   b'became\r\n',
#   b'because\r\n',
#   b'become\r\n',
#   b'becomes\r\n',
#   b'becoming\r\n',
#   b'been\r\n',
#   b'before\r\n',
#   b'beforehand\r\n',
#   b'behind\r\n',
#   b'being\r\n',
#   b'believe\r\n',
#   b'below\r\n',
#   b'beside\r\n',
#   b'besides\r\n',
#   b'best\r\n',
#   b'better\r\n',
#   b'between\r\n',
#   b'beyond\r\n',
#   b'both\r\n',
#   b'brief\r\n',
#   b'but\r\n',
#   b'by\r\n',
#   b'c\r\n',
#   b"c'mon\r\n",
#   b"c's\r\n",
#   b'came\r\n',
#   b'can\r\n',
#   b"can't\r\n",
#   b'cannot\r\n',
#   b'cant\r\n',
#   b'cause\r\n',
#   b'causes\r\n',
#   b'certain\r\n',
#   b'certainly\r\n',
#   b'changes\r\n',
#   b'clearly\r\n',
#   b'co\r\n',
#   b'com\r\n',
#   b'come\r\n',
#   b'comes\r\n',
#   b'concerning\r\n',
#   b'consequently\r\n',
#   b'consider\r\n',
#   b'considering\r\n',
#   b'contain\r\n',
#   b'containing\r\n',
#   b'contains\r\n',
#   b'corresponding\r\n',
#   b'could\r\n',
#   b"couldn't\r\n",
#   b'course\r\n',
#   b'currently\r\n',
#   b'd\r\n',
#   b'definitely\r\n',
#   b'described\r\n',
#   b'despite\r\n',
#   b'did\r\n',
#   b"didn't\r\n",
#   b'different\r\n',
#   b'do\r\n',
#   b'does\r\n',
#   b"doesn't\r\n",
#   b'doing\r\n',
#   b"don't\r\n",
#   b'done\r\n',
#   b'down\r\n',
#   b'downwards\r\n',
#   b'during\r\n',
#   b'e\r\n',
#   b'each\r\n',
#   b'edu\r\n',
#   b'eg\r\n',
#   b'eight\r\n',
#   b'either\r\n',
#   b'else\r\n',
#   b'elsewhere\r\n',
#   b'enough\r\n',
#   b'entirely\r\n',
#   b'especially\r\n',
#   b'et\r\n',
#   b'etc\r\n',
#   b'even\r\n',
#   b'ever\r\n',
#   b'every\r\n',
#   b'everybody\r\n',
#   b'everyone\r\n',
#   b'everything\r\n',
#   b'everywhere\r\n',
#   b'ex\r\n',
#   b'exactly\r\n',
#   b'example\r\n',
#   b'except\r\n',
#   b'f\r\n',
#   b'far\r\n',
#   b'few\r\n',
#   b'fifth\r\n',
#   b'first\r\n',
#   b'five\r\n',
#   b'followed\r\n',
#   b'following\r\n',
#   b'follows\r\n',
#   b'for\r\n',
#   b'former\r\n',
#   b'formerly\r\n',
#   b'forth\r\n',
#   b'four\r\n',
#   b'from\r\n',
#   b'further\r\n',
#   b'furthermore\r\n',
#   b'g\r\n',
#   b'get\r\n',
#   b'gets\r\n',
#   b'getting\r\n',
#   b'given\r\n',
#   b'gives\r\n',
#   b'go\r\n',
#   b'goes\r\n',
#   b'going\r\n',
#   b'gone\r\n',
#   b'got\r\n',
#   b'gotten\r\n',
#   b'greetings\r\n',
#   b'h\r\n',
#   b'had\r\n',
#   b"hadn't\r\n",
#   b'happens\r\n',
#   b'hardly\r\n',
#   b'has\r\n',
#   b"hasn't\r\n",
#   b'have\r\n',
#   b"haven't\r\n",
#   b'having\r\n',
#   b'he\r\n',
#   b"he's\r\n",
#   b'hello\r\n',
#   b'help\r\n',
#   b'hence\r\n',
#   b'her\r\n',
#   b'here\r\n',
#   b"here's\r\n",
#   b'hereafter\r\n',
#   b'hereby\r\n',
#   b'herein\r\n',
#   b'hereupon\r\n',
#   b'hers\r\n',
#   b'herself\r\n',
#   b'hi\r\n',
#   b'him\r\n',
#   b'himself\r\n',
#   b'his\r\n',
#   b'hither\r\n',
#   b'hopefully\r\n',
#   b'how\r\n',
#   b'howbeit\r\n',
#   b'however\r\n',
#   b'i\r\n',
#   b"i'd\r\n",
#   b"i'll\r\n",
#   b"i'm\r\n",
#   b"i've\r\n",
#   b'ie\r\n',
#   b'if\r\n',
#   b'ignored\r\n',
#   b'immediate\r\n',
#   b'in\r\n',
#   b'inasmuch\r\n',
#   b'inc\r\n',
#   b'indeed\r\n',
#   b'indicate\r\n',
#   b'indicated\r\n',
#   b'indicates\r\n',
#   b'inner\r\n',
#   b'insofar\r\n',
#   b'instead\r\n',
#   b'into\r\n',
#   b'inward\r\n',
#   b'is\r\n',
#   b"isn't\r\n",
#   b'it\r\n',
#   b"it'd\r\n",
#   b"it'll\r\n",
#   b"it's\r\n",
#   b'its\r\n',
#   b'itself\r\n',
#   b'j\r\n',
#   b'just\r\n',
#   b'k\r\n',
#   b'keep\r\n',
#   b'keeps\r\n',
#   b'kept\r\n',
#   b'know\r\n',
#   b'knows\r\n',
#   b'known\r\n',
#   b'l\r\n',
#   b'last\r\n',
#   b'lately\r\n',
#   b'later\r\n',
#   b'latter\r\n',
#   b'latterly\r\n',
#   b'least\r\n',
#   b'less\r\n',
#   b'lest\r\n',
#   b'let\r\n',
#   b"let's\r\n",
#   b'like\r\n',
#   b'liked\r\n',
#   b'likely\r\n',
#   b'little\r\n',
#   b'look\r\n',
#   b'looking\r\n',
#   b'looks\r\n',
#   b'ltd\r\n',
#   b'm\r\n',
#   b'mainly\r\n',
#   b'many\r\n',
#   b'may\r\n',
#   b'maybe\r\n',
#   b'me\r\n',
#   b'mean\r\n',
#   b'meanwhile\r\n',
#   b'merely\r\n',
#   b'might\r\n',
#   b'more\r\n',
#   b'moreover\r\n',
#   b'most\r\n',
#   b'mostly\r\n',
#   b'much\r\n',
#   b'must\r\n',
#   b'my\r\n',
#   b'myself\r\n',
#   b'n\r\n',
#   b'name\r\n',
#   b'namely\r\n',
#   b'nd\r\n',
#   b'near\r\n',
#   b'nearly\r\n',
#   b'necessary\r\n',
#   b'need\r\n',
#   b'needs\r\n',
#   b'neither\r\n',
#   b'never\r\n',
#   b'nevertheless\r\n',
#   b'new\r\n',
#   b'next\r\n',
#   b'nine\r\n',
#   b'no\r\n',
#   b'nobody\r\n',
#   b'non\r\n',
#   b'none\r\n',
#   b'noone\r\n',
#   b'nor\r\n',
#   b'normally\r\n',
#   b'not\r\n',
#   b'nothing\r\n',
#   b'novel\r\n',
#   b'now\r\n',
#   b'nowhere\r\n',
#   b'o\r\n',
#   b'obviously\r\n',
#   b'of\r\n',
#   b'off\r\n',
#   b'often\r\n',
#   b'oh\r\n',
#   b'ok\r\n',
#   b'okay\r\n',
#   b'old\r\n',
#   b'on\r\n',
#   b'once\r\n',
#   b'one\r\n',
#   b'ones\r\n',
#   b'only\r\n',
#   b'onto\r\n',
#   b'or\r\n',
#   b'other\r\n',
#   b'others\r\n',
#   b'otherwise\r\n',
#   b'ought\r\n',
#   b'our\r\n',
#   b'ours\r\n',
#   b'ourselves\r\n',
#   b'out\r\n',
#   b'outside\r\n',
#   b'over\r\n',
#   b'overall\r\n',
#   b'own\r\n',
#   b'p\r\n',
#   b'particular\r\n',
#   b'particularly\r\n',
#   b'per\r\n',
#   b'perhaps\r\n',
#   b'placed\r\n',
#   b'please\r\n',
#   b'plus\r\n',
#   b'possible\r\n',
#   b'presumably\r\n',
#   b'probably\r\n',
#   b'provides\r\n',
#   b'q\r\n',
#   b'que\r\n',
#   b'quite\r\n',
#   b'qv\r\n',
#   b'r\r\n',
#   b'rather\r\n',
#   b'rd\r\n',
#   b're\r\n',
#   b'really\r\n',
#   b'reasonably\r\n',
#   b'regarding\r\n',
#   b'regardless\r\n',
#   b'regards\r\n',
#   b'relatively\r\n',
#   b'respectively\r\n',
#   b'right\r\n',
#   b's\r\n',
#   b'said\r\n',
#   b'same\r\n',
#   b'saw\r\n',
#   b'say\r\n',
#   b'saying\r\n',
#   b'says\r\n',
#   b'second\r\n',
#   b'secondly\r\n',
#   b'see\r\n',
#   b'seeing\r\n',
#   b'seem\r\n',
#   b'seemed\r\n',
#   b'seeming\r\n',
#   b'seems\r\n',
#   b'seen\r\n',
#   b'self\r\n',
#   b'selves\r\n',
#   b'sensible\r\n',
#   b'sent\r\n',
#   b'serious\r\n',
#   b'seriously\r\n',
#   b'seven\r\n',
#   b'several\r\n',
#   b'shall\r\n',
#   b'she\r\n',
#   b'should\r\n',
#   b"shouldn't\r\n",
#   b'since\r\n',
#   b'six\r\n',
#   b'so\r\n',
#   b'some\r\n',
#   b'somebody\r\n',
#   b'somehow\r\n',
#   b'someone\r\n',
#   b'something\r\n',
#   b'sometime\r\n',
#   b'sometimes\r\n',
#   b'somewhat\r\n',
#   b'somewhere\r\n',
#   b'soon\r\n',
#   b'sorry\r\n',
#   b'specified\r\n',
#   b'specify\r\n',
#   b'specifying\r\n',
#   b'still\r\n',
#   b'sub\r\n',
#   b'such\r\n',
#   b'sup\r\n',
#   b'sure\r\n',
#   b't\r\n',
#   b"t's\r\n",
#   b'take\r\n',
#   b'taken\r\n',
#   b'tell\r\n',
#   b'tends\r\n',
#   b'th\r\n',
#   b'than\r\n',
#   b'thank\r\n',
#   b'thanks\r\n',
#   b'thanx\r\n',
#   b'that\r\n',
#   b"that's\r\n",
#   b'thats\r\n',
#   b'the\r\n',
#   b'their\r\n',
#   b'theirs\r\n',
#   b'them\r\n',
#   b'themselves\r\n',
#   b'then\r\n',
#   b'thence\r\n',
#   b'there\r\n',
#   b"there's\r\n",
#   b'thereafter\r\n',
#   b'thereby\r\n',
#   b'therefore\r\n',
#   b'therein\r\n',
#   b'theres\r\n',
#   b'thereupon\r\n',
#   b'these\r\n',
#   b'they\r\n',
#   b"they'd\r\n",
#   b"they'll\r\n",
#   b"they're\r\n",
#   b"they've\r\n",
#   b'think\r\n',
#   b'third\r\n',
#   b'this\r\n',
#   b'thorough\r\n',
#   b'thoroughly\r\n',
#   b'those\r\n',
#   b'though\r\n',
#   b'three\r\n',
#   b'through\r\n',
#   b'throughout\r\n',
#   b'thru\r\n',
#   b'thus\r\n',
#   b'to\r\n',
#   b'together\r\n',
#   b'too\r\n',
#   b'took\r\n',
#   b'toward\r\n',
#   b'towards\r\n',
#   b'tried\r\n',
#   b'tries\r\n',
#   b'truly\r\n',
#   b'try\r\n',
#   b'trying\r\n',
#   b'twice\r\n',
#   b'two\r\n',
#   b'u\r\n',
#   b'un\r\n',
#   b'under\r\n',
#   b'unfortunately\r\n',
#   b'unless\r\n',
#   b'unlikely\r\n',
#   b'until\r\n',
#   b'unto\r\n',
#   b'up\r\n',
#   b'upon\r\n',
#   b'us\r\n',
#   b'use\r\n',
#   b'used\r\n',
#   b'useful\r\n',
#   b'uses\r\n',
#   b'using\r\n',
#   b'usually\r\n',
#   b'uucp\r\n',
#   b'v\r\n',
#   b'value\r\n',
#   b'various\r\n',
#   b'very\r\n',
#   b'via\r\n',
#   b'viz\r\n',
#   b'vs\r\n',
#   b'w\r\n',
#   b'want\r\n',
#   b'wants\r\n',
#   b'was\r\n',
#   b"wasn't\r\n",
#   b'way\r\n',
#   b'we\r\n',
#   b"we'd\r\n",
#   b"we'll\r\n",
#   b"we're\r\n",
#   b"we've\r\n",
#   b'welcome\r\n',
#   b'well\r\n',
#   b'went\r\n',
#   b'were\r\n',
#   b"weren't\r\n",
#   b'what\r\n',
#   b"what's\r\n",
#   b'whatever\r\n',
#   b'when\r\n',
#   b'whence\r\n',
#   b'whenever\r\n',
#   b'where\r\n',
#   b"where's\r\n",
#   b'whereafter\r\n',
#   b'whereas\r\n',
#   b'whereby\r\n',
#   b'wherein\r\n',
#   b'whereupon\r\n',
#   b'wherever\r\n',
#   b'whether\r\n',
#   b'which\r\n',
#   b'while\r\n',
#   b'whither\r\n',
#   b'who\r\n',
#   b"who's\r\n",
#   b'whoever\r\n',
#   b'whole\r\n',
#   b'whom\r\n',
#   b'whose\r\n',
#   b'why\r\n',
#   b'will\r\n',
#   b'willing\r\n',
#   b'wish\r\n',
#   b'with\r\n',
#   b'within\r\n',
#   b'without\r\n',
#   b"won't\r\n",
#   b'wonder\r\n',
#   b'would\r\n',
#   b'would\r\n',
#   b"wouldn't\r\n",
#   b'x\r\n',
#   b'y\r\n',
#   b'yes\r\n',
#   b'yet\r\n',
#   b'you\r\n',
#   b"you'd\r\n",
#   b"you'll\r\n",
#   b"you're\r\n",
#   b"you've\r\n",
#   b'your\r\n',
#   b'yours\r\n',
#   b'yourself\r\n',
#   b'yourselves\r\n',
#   b'z\r\n',
#   b'zero'],
#  [b'UNITED  | Geographic\r\n',
#   b'STATE\r\n',
#   b'NORTH\r\n',
#   b'SOUTH\r\n',
#   b'EAST\r\n',
#   b'NORTHEAST\r\n',
#   b'NORTHWEST\r\n',
#   b'SOUTHEAST\r\n',
#   b'SOUTHWEST\r\n',
#   b'WEST\r\n',
#   b'OCEAN\r\n',
#   b'SEA\r\n',
#   b'LAKE\r\n',
#   b'RIVER\r\n',
#   b'CREEK\r\n',
#   b'GULF\r\n',
#   b'MOUNTAIN\r\n',
#   b'STREET\r\n',
#   b'BOULEVARD\r\n',
#   b'BLVD\r\n',
#   b'PARKWAY\r\n',
#   b'CITY\r\n',
#   b'COUNTY\r\n',
#   b'COUNTRY\r\n',
#   b'PACIFIC\r\n',
#   b'ATLANTIC\r\n',
#   b'INDIAN\r\n',
#   b'MEDITERRANEAN\r\n',
#   b'COMMONWEALTH\r\n',
#   b'AMERICA\r\n',
#   b'AMERICAN\r\n',
#   b'YORK  | Cities\r\n',
#   b'CHICAGO\r\n',
#   b'LAS\r\n',
#   b'VEGAS\r\n',
#   b'LOS\r\n',
#   b'ANGELES\r\n',
#   b'MILWAUKEE\r\n',
#   b'SUNNYVALE\r\n',
#   b'FREMONT\r\n',
#   b'CINCINNATI\r\n',
#   b'PHILADELPHIA\r\n',
#   b'MIAMI\r\n',
#   b'DALLAS\r\n',
#   b'FORT\r\n',
#   b'BOSTON\r\n',
#   b'HOUSTON\r\n',
#   b'WASHINGTON\r\n',
#   b'ATLANTA\r\n',
#   b'DETROIT\r\n',
#   b'SAN\r\n',
#   b'FRANSICO\r\n',
#   b'PHOENIX\r\n',
#   b'SEATTLE\r\n',
#   b'DIEGO\r\n',
#   b'MINNEAPOLIS\r\n',
#   b'MEMPHIS\r\n',
#   b'DENVER\r\n',
#   b'ST\r\n',
#   b'LOUIS\r\n',
#   b'PITTSBURGH\r\n',
#   b'MANHATTAN\r\n',
#   b'HOLLYWOOD\r\n',
#   b'COLUMBUS\r\n',
#   b'INDIANAPOLIS\r\n',
#   b'MUMBAI\r\n',
#   b'KARACHI\r\n',
#   b'ONTARIO\r\n',
#   b'TORONTO\r\n',
#   b'CAMBRIDGE\r\n',
#   b'DELHI\r\n',
#   b'SAO\r\n',
#   b'PAULO\r\n',
#   b'SHANGHAI\r\n',
#   b'MOSCOW\r\n',
#   b'SEOUL\r\n',
#   b'ISTANBUL\r\n',
#   b'TOKYO\r\n',
#   b'JAKARTA\r\n',
#   b'BEIJING\r\n',
#   b'LONDON\r\n',
#   b'LUXEMBOURG\r\n',
#   b'SINGAPORE\r\n',
#   b'REPUBLIC  | Countries\r\n',
#   b'CHINA\r\n',
#   b'INDIA\r\n',
#   b'INDONESIA\r\n',
#   b'BRAZIL\r\n',
#   b'BRAZILIAN\r\n',
#   b'PAKISTAN\r\n',
#   b'BANGLADESH\r\n',
#   b'RUSSIA\r\n',
#   b'NIGERIA\r\n',
#   b'NOVA\r\n',
#   b'SCOTIA\r\n',
#   b'JAPAN\r\n',
#   b'MALAYSIA\r\n',
#   b'MEXICO\r\n',
#   b'MEXICAN\r\n',
#   b'PHILIPPINES\r\n',
#   b'VIETNAM\r\n',
#   b'GERMANY\r\n',
#   b'FRANCE\r\n',
#   b'KOREA\r\n',
#   b'SPAIN\r\n',
#   b'ARGENTINA\r\n',
#   b'BERMUDA\r\n',
#   b'COLUMBIA\r\n',
#   b'PUERTO\r\n',
#   b'CANADA\r\n',
#   b'CANADIAN\r\n',
#   b'AFRICA\r\n',
#   b'AFRICAN\r\n',
#   b'CHILE\r\n',
#   b'CHILEAN\r\n',
#   b'EUROPE\r\n',
#   b'EUROPEAN\r\n',
#   b'USA\r\n',
#   b'ITALY\r\n',
#   b'ITALIAN\r\n',
#   b'AUSTRALIA\r\n',
#   b'NETHERLANDS\r\n',
#   b'NORWAY\r\n',
#   b'PORTUGAL\r\n',
#   b'TAIWAN\r\n',
#   b'ARGENTINA\r\n',
#   b'SWITZERLAND\r\n',
#   b'SWISS\r\n',
#   b'SUISSE\r\n',
#   b'DENMARK\r\n',
#   b'CZECK\r\n',
#   b'HUNGARY\r\n',
#   b'FINLAND\r\n',
#   b'SCOTLAND\r\n',
#   b'COSTA\r\n',
#   b'RICA\r\n',
#   b'SWEDEN\r\n',
#   b'BELGIUM\r\n',
#   b'AUSTRIA\r\n',
#   b'TURKEY\r\n',
#   b'POLAND\r\n',
#   b'INDONESIA\r\n',
#   b'THAILAND\r\n',
#   b'VENEZUELA\r\n',
#   b'ASIA\r\n',
#   b'ZEALAND\r\n',
#   b'JAPANESE\r\n',
#   b'LATIN\r\n',
#   b'BRITISH\r\n',
#   b'CHINESE\r\n',
#   b'ALABAMA   | States\r\n',
#   b'ALASKA\r\n',
#   b'ARIZONA\r\n',
#   b'ARKANSAS\r\n',
#   b'CALIFORNIA\r\n',
#   b'COLORADO\r\n',
#   b'CONNECTICUT\r\n',
#   b'DELAWARE\r\n',
#   b'FLORIDA\r\n',
#   b'GEORGIA\r\n',
#   b'HAWAII\r\n',
#   b'IDAHO\r\n',
#   b'ILLINOIS\r\n',
#   b'INDIANA\r\n',
#   b'IOWA\r\n',
#   b'KANSAS\r\n',
#   b'KENTUCKY\r\n',
#   b'LOUISIANA\r\n',
#   b'MAINE\r\n',
#   b'MARYLAND\r\n',
#   b'MASSACHUSETTS\r\n',
#   b'MICHIGAN\r\n',
#   b'MINNESOTA\r\n',
#   b'MISSISSIPPI\r\n',
#   b'MISSOURI\r\n',
#   b'MONTANA\r\n',
#   b'NEBRASKA\r\n',
#   b'NEVADA\r\n',
#   b'HAMPSHIRE\r\n',
#   b'JERSEY\r\n',
#   b'MEXICO\r\n',
#   b'NEW\r\n',
#   b'YORK\r\n',
#   b'OHIO\r\n',
#   b'OKLAHOMA\r\n',
#   b'OREGON\r\n',
#   b'PENNSYLVANIA\r\n',
#   b'RHODE\r\n',
#   b'ISLAND\r\n',
#   b'CAROLINA\r\n',
#   b'DAKOTA\r\n',
#   b'TENNESSEE\r\n',
#   b'TEXAS\r\n',
#   b'UTAH\r\n',
#   b'VERMONT\r\n',
#   b'VIRGINIA\r\n',
#   b'WASHINGTON\r\n',
#   b'WISCONSIN\r\n',
#   b'WYOMING\r\n'],
#  [b'SMITH  | Surnames from 1990 census > .002%.  www.census.gov.genealogy/names/dist.all.last\r\n',
#   b'JOHNSON\r\n',
#   b'WILLIAMS\r\n',
#   b'JONES\r\n',
#   b'BROWN\r\n',
#   b'DAVIS\r\n',
#   b'MILLER\r\n',
#   b'WILSON\r\n',
#   b'MOORE\r\n',
#   b'TAYLOR\r\n',
#   b'ANDERSON\r\n',
#   b'THOMAS\r\n',
#   b'JACKSON\r\n',
#   b'WHITE\r\n',
#   b'HARRIS\r\n',
#   b'MARTIN\r\n',
#   b'THOMPSON\r\n',
#   b'GARCIA\r\n',
#   b'MARTINEZ\r\n',
#   b'ROBINSON\r\n',
#   b'CLARK\r\n',
#   b'RODRIGUEZ\r\n',
#   b'LEWIS\r\n',
#   b'LEE\r\n',
#   b'WALKER\r\n',
#   b'HALL\r\n',
#   b'ALLEN\r\n',
#   b'YOUNG\r\n',
#   b'HERNANDEZ\r\n',
#   b'KING\r\n',
#   b'WRIGHT\r\n',
#   b'LOPEZ\r\n',
#   b'HILL\r\n',
#   b'SCOTT\r\n',
#   b'GREEN\r\n',
#   b'ADAMS\r\n',
#   b'BAKER\r\n',
#   b'GONZALEZ\r\n',
#   b'NELSON\r\n',
#   b'CARTER\r\n',
#   b'MITCHELL\r\n',
#   b'PEREZ\r\n',
#   b'ROBERTS\r\n',
#   b'TURNER\r\n',
#   b'PHILLIPS\r\n',
#   b'CAMPBELL\r\n',
#   b'PARKER\r\n',
#   b'EVANS\r\n',
#   b'EDWARDS\r\n',
#   b'COLLINS\r\n',
#   b'STEWART\r\n',
#   b'SANCHEZ\r\n',
#   b'MORRIS\r\n',
#   b'ROGERS\r\n',
#   b'REED\r\n',
#   b'COOK\r\n',
#   b'MORGAN\r\n',
#   b'BELL\r\n',
#   b'MURPHY\r\n',
#   b'BAILEY\r\n',
#   b'RIVERA\r\n',
#   b'COOPER\r\n',
#   b'RICHARDSON\r\n',
#   b'COX\r\n',
#   b'HOWARD\r\n',
#   b'WARD\r\n',
#   b'TORRES\r\n',
#   b'PETERSON\r\n',
#   b'GRAY\r\n',
#   b'RAMIREZ\r\n',
#   b'JAMES\r\n',
#   b'WATSON\r\n',
#   b'BROOKS\r\n',
#   b'KELLY\r\n',
#   b'SANDERS\r\n',
#   b'PRICE\r\n',
#   b'BENNETT\r\n',
#   b'WOOD\r\n',
#   b'BARNES\r\n',
#   b'ROSS\r\n',
#   b'HENDERSON\r\n',
#   b'COLEMAN\r\n',
#   b'JENKINS\r\n',
#   b'PERRY\r\n',
#   b'POWELL\r\n',
#   b'LONG\r\n',
#   b'PATTERSON\r\n',
#   b'HUGHES\r\n',
#   b'FLORES\r\n',
#   b'WASHINGTON\r\n',
#   b'BUTLER\r\n',
#   b'SIMMONS\r\n',
#   b'FOSTER\r\n',
#   b'GONZALES\r\n',
#   b'BRYANT\r\n',
#   b'ALEXANDER\r\n',
#   b'RUSSELL\r\n',
#   b'GRIFFIN\r\n',
#   b'DIAZ\r\n',
#   b'HAYES\r\n',
#   b'MYERS\r\n',
#   b'FORD\r\n',
#   b'HAMILTON\r\n',
#   b'GRAHAM\r\n',
#   b'SULLIVAN\r\n',
#   b'WALLACE\r\n',
#   b'WOODS\r\n',
#   b'COLE\r\n',
#   b'WEST\r\n',
#   b'JORDAN\r\n',
#   b'OWENS\r\n',
#   b'REYNOLDS\r\n',
#   b'FISHER\r\n',
#   b'ELLIS\r\n',
#   b'HARRISON\r\n',
#   b'GIBSON\r\n',
#   b'MCDONALD\r\n',
#   b'CRUZ\r\n',
#   b'MARSHALL\r\n',
#   b'ORTIZ\r\n',
#   b'GOMEZ\r\n',
#   b'MURRAY\r\n',
#   b'FREEMAN\r\n',
#   b'WELLS\r\n',
#   b'WEBB\r\n',
#   b'SIMPSON\r\n',
#   b'STEVENS\r\n',
#   b'TUCKER\r\n',
#   b'PORTER\r\n',
#   b'HUNTER\r\n',
#   b'HICKS\r\n',
#   b'CRAWFORD\r\n',
#   b'HENRY\r\n',
#   b'BOYD\r\n',
#   b'MASON\r\n',
#   b'MORALES\r\n',
#   b'KENNEDY\r\n',
#   b'WARREN\r\n',
#   b'DIXON\r\n',
#   b'RAMOS\r\n',
#   b'REYES\r\n',
#   b'BURNS\r\n',
#   b'GORDON\r\n',
#   b'SHAW\r\n',
#   b'HOLMES\r\n',
#   b'RICE\r\n',
#   b'ROBERTSON\r\n',
#   b'HUNT\r\n',
#   b'BLACK\r\n',
#   b'DANIELS\r\n',
#   b'PALMER\r\n',
#   b'MILLS\r\n',
#   b'NICHOLS\r\n',
#   b'GRANT\r\n',
#   b'KNIGHT\r\n',
#   b'FERGUSON\r\n',
#   b'ROSE\r\n',
#   b'STONE\r\n',
#   b'HAWKINS\r\n',
#   b'DUNN\r\n',
#   b'PERKINS\r\n',
#   b'HUDSON\r\n',
#   b'SPENCER\r\n',
#   b'GARDNER\r\n',
#   b'STEPHENS\r\n',
#   b'PAYNE\r\n',
#   b'PIERCE\r\n',
#   b'BERRY\r\n',
#   b'MATTHEWS\r\n',
#   b'ARNOLD\r\n',
#   b'WAGNER\r\n',
#   b'WILLIS\r\n',
#   b'RAY\r\n',
#   b'WATKINS\r\n',
#   b'OLSON\r\n',
#   b'CARROLL\r\n',
#   b'DUNCAN\r\n',
#   b'SNYDER\r\n',
#   b'HART\r\n',
#   b'CUNNINGHAM\r\n',
#   b'BRADLEY\r\n',
#   b'LANE\r\n',
#   b'ANDREWS\r\n',
#   b'RUIZ\r\n',
#   b'HARPER\r\n',
#   b'FOX\r\n',
#   b'RILEY\r\n',
#   b'ARMSTRONG\r\n',
#   b'CARPENTER\r\n',
#   b'WEAVER\r\n',
#   b'GREENE\r\n',
#   b'LAWRENCE\r\n',
#   b'ELLIOTT\r\n',
#   b'CHAVEZ\r\n',
#   b'SIMS\r\n',
#   b'AUSTIN\r\n',
#   b'PETERS\r\n',
#   b'KELLEY\r\n',
#   b'FRANKLIN\r\n',
#   b'LAWSON\r\n',
#   b'FIELDS\r\n',
#   b'GUTIERREZ\r\n',
#   b'RYAN\r\n',
#   b'SCHMIDT\r\n',
#   b'CARR\r\n',
#   b'VASQUEZ\r\n',
#   b'CASTILLO\r\n',
#   b'WHEELER\r\n',
#   b'CHAPMAN\r\n',
#   b'OLIVER\r\n',
#   b'MONTGOMERY\r\n',
#   b'RICHARDS\r\n',
#   b'WILLIAMSON\r\n',
#   b'JOHNSTON\r\n',
#   b'BANKS\r\n',
#   b'MEYER\r\n',
#   b'BISHOP\r\n',
#   b'MCCOY\r\n',
#   b'HOWELL\r\n',
#   b'ALVAREZ\r\n',
#   b'MORRISON\r\n',
#   b'HANSEN\r\n',
#   b'FERNANDEZ\r\n',
#   b'GARZA\r\n',
#   b'HARVEY\r\n',
#   b'LITTLE\r\n',
#   b'BURTON\r\n',
#   b'STANLEY\r\n',
#   b'NGUYEN\r\n',
#   b'GEORGE\r\n',
#   b'JACOBS\r\n',
#   b'REID\r\n',
#   b'KIM\r\n',
#   b'FULLER\r\n',
#   b'LYNCH\r\n',
#   b'DEAN\r\n',
#   b'GILBERT\r\n',
#   b'GARRETT\r\n',
#   b'ROMERO\r\n',
#   b'WELCH\r\n',
#   b'LARSON\r\n',
#   b'FRAZIER\r\n',
#   b'BURKE\r\n',
#   b'HANSON\r\n',
#   b'DAY\r\n',
#   b'MENDOZA\r\n',
#   b'MORENO\r\n',
#   b'BOWMAN\r\n',
#   b'MEDINA\r\n',
#   b'FOWLER\r\n',
#   b'BREWER\r\n',
#   b'HOFFMAN\r\n',
#   b'CARLSON\r\n',
#   b'SILVA\r\n',
#   b'PEARSON\r\n',
#   b'HOLLAND\r\n',
#   b'DOUGLAS\r\n',
#   b'FLEMING\r\n',
#   b'JENSEN\r\n',
#   b'VARGAS\r\n',
#   b'BYRD\r\n',
#   b'DAVIDSON\r\n',
#   b'HOPKINS\r\n',
#   b'MAY\r\n',
#   b'TERRY\r\n',
#   b'HERRERA\r\n',
#   b'WADE\r\n',
#   b'SOTO\r\n',
#   b'WALTERS\r\n',
#   b'CURTIS\r\n',
#   b'NEAL\r\n',
#   b'CALDWELL\r\n',
#   b'LOWE\r\n',
#   b'JENNINGS\r\n',
#   b'BARNETT\r\n',
#   b'GRAVES\r\n',
#   b'JIMENEZ\r\n',
#   b'HORTON\r\n',
#   b'SHELTON\r\n',
#   b'BARRETT\r\n',
#   b'OBRIEN\r\n',
#   b'CASTRO\r\n',
#   b'SUTTON\r\n',
#   b'GREGORY\r\n',
#   b'MCKINNEY\r\n',
#   b'LUCAS\r\n',
#   b'MILES\r\n',
#   b'CRAIG\r\n',
#   b'RODRIQUEZ\r\n',
#   b'CHAMBERS\r\n',
#   b'HOLT\r\n',
#   b'LAMBERT\r\n',
#   b'FLETCHER\r\n',
#   b'WATTS\r\n',
#   b'BATES\r\n',
#   b'HALE\r\n',
#   b'RHODES\r\n',
#   b'PENA\r\n',
#   b'BECK\r\n',
#   b'NEWMAN\r\n',
#   b'HAYNES\r\n',
#   b'MCDANIEL\r\n',
#   b'MENDEZ\r\n',
#   b'BUSH\r\n',
#   b'VAUGHN\r\n',
#   b'PARKS\r\n',
#   b'DAWSON\r\n',
#   b'SANTIAGO\r\n',
#   b'NORRIS\r\n',
#   b'HARDY\r\n',
#   b'LOVE\r\n',
#   b'STEELE\r\n',
#   b'CURRY\r\n',
#   b'POWERS\r\n',
#   b'SCHULTZ\r\n',
#   b'BARKER\r\n',
#   b'GUZMAN\r\n',
#   b'PAGE\r\n',
#   b'MUNOZ\r\n',
#   b'BALL\r\n',
#   b'KELLER\r\n',
#   b'CHANDLER\r\n',
#   b'WEBER\r\n',
#   b'LEONARD\r\n',
#   b'WALSH\r\n',
#   b'LYONS\r\n',
#   b'RAMSEY\r\n',
#   b'WOLFE\r\n',
#   b'SCHNEIDER\r\n',
#   b'MULLINS\r\n',
#   b'BENSON\r\n',
#   b'SHARP\r\n',
#   b'BOWEN\r\n',
#   b'DANIEL\r\n',
#   b'BARBER\r\n',
#   b'CUMMINGS\r\n',
#   b'HINES\r\n',
#   b'BALDWIN\r\n',
#   b'GRIFFITH\r\n',
#   b'VALDEZ\r\n',
#   b'HUBBARD\r\n',
#   b'SALAZAR\r\n',
#   b'REEVES\r\n',
#   b'WARNER\r\n',
#   b'STEVENSON\r\n',
#   b'BURGESS\r\n',
#   b'SANTOS\r\n',
#   b'TATE\r\n',
#   b'CROSS\r\n',
#   b'GARNER\r\n',
#   b'MANN\r\n',
#   b'MACK\r\n',
#   b'MOSS\r\n',
#   b'THORNTON\r\n',
#   b'DENNIS\r\n',
#   b'MCGEE\r\n',
#   b'FARMER\r\n',
#   b'DELGADO\r\n',
#   b'AGUILAR\r\n',
#   b'VEGA\r\n',
#   b'GLOVER\r\n',
#   b'MANNING\r\n',
#   b'COHEN\r\n',
#   b'HARMON\r\n',
#   b'RODGERS\r\n',
#   b'ROBBINS\r\n',
#   b'NEWTON\r\n',
#   b'TODD\r\n',
#   b'BLAIR\r\n',
#   b'HIGGINS\r\n',
#   b'INGRAM\r\n',
#   b'REESE\r\n',
#   b'CANNON\r\n',
#   b'STRICKLAND\r\n',
#   b'TOWNSEND\r\n',
#   b'POTTER\r\n',
#   b'GOODWIN\r\n',
#   b'WALTON\r\n',
#   b'ROWE\r\n',
#   b'HAMPTON\r\n',
#   b'ORTEGA\r\n',
#   b'PATTON\r\n',
#   b'SWANSON\r\n',
#   b'JOSEPH\r\n',
#   b'FRANCIS\r\n',
#   b'GOODMAN\r\n',
#   b'MALDONADO\r\n',
#   b'YATES\r\n',
#   b'BECKER\r\n',
#   b'ERICKSON\r\n',
#   b'HODGES\r\n',
#   b'RIOS\r\n',
#   b'CONNER\r\n',
#   b'ADKINS\r\n',
#   b'WEBSTER\r\n',
#   b'NORMAN\r\n',
#   b'MALONE\r\n',
#   b'HAMMOND\r\n',
#   b'FLOWERS\r\n',
#   b'COBB\r\n',
#   b'MOODY\r\n',
#   b'QUINN\r\n',
#   b'BLAKE\r\n',
#   b'MAXWELL\r\n',
#   b'POPE\r\n',
#   b'FLOYD\r\n',
#   b'OSBORNE\r\n',
#   b'PAUL\r\n',
#   b'MCCARTHY\r\n',
#   b'GUERRERO\r\n',
#   b'LINDSEY\r\n',
#   b'ESTRADA\r\n',
#   b'SANDOVAL\r\n',
#   b'GIBBS\r\n',
#   b'TYLER\r\n',
#   b'GROSS\r\n',
#   b'FITZGERALD\r\n',
#   b'STOKES\r\n',
#   b'DOYLE\r\n',
#   b'SHERMAN\r\n',
#   b'SAUNDERS\r\n',
#   b'WISE\r\n',
#   b'COLON\r\n',
#   b'GILL\r\n',
#   b'ALVARADO\r\n',
#   b'GREER\r\n',
#   b'PADILLA\r\n',
#   b'SIMON\r\n',
#   b'WATERS\r\n',
#   b'NUNEZ\r\n',
#   b'BALLARD\r\n',
#   b'SCHWARTZ\r\n',
#   b'MCBRIDE\r\n',
#   b'HOUSTON\r\n',
#   b'CHRISTENSEN\r\n',
#   b'KLEIN\r\n',
#   b'PRATT\r\n',
#   b'BRIGGS\r\n',
#   b'PARSONS\r\n',
#   b'MCLAUGHLIN\r\n',
#   b'ZIMMERMAN\r\n',
#   b'FRENCH\r\n',
#   b'BUCHANAN\r\n',
#   b'MORAN\r\n',
#   b'COPELAND\r\n',
#   b'ROY\r\n',
#   b'PITTMAN\r\n',
#   b'BRADY\r\n',
#   b'MCCORMICK\r\n',
#   b'HOLLOWAY\r\n',
#   b'BROCK\r\n',
#   b'POOLE\r\n',
#   b'FRANK\r\n',
#   b'LOGAN\r\n',
#   b'OWEN\r\n',
#   b'BASS\r\n',
#   b'MARSH\r\n',
#   b'DRAKE\r\n',
#   b'WONG\r\n',
#   b'JEFFERSON\r\n',
#   b'PARK\r\n',
#   b'MORTON\r\n',
#   b'ABBOTT\r\n',
#   b'SPARKS\r\n',
#   b'PATRICK\r\n',
#   b'NORTON\r\n',
#   b'HUFF\r\n',
#   b'CLAYTON\r\n',
#   b'MASSEY\r\n',
#   b'LLOYD\r\n',
#   b'FIGUEROA\r\n',
#   b'CARSON\r\n',
#   b'BOWERS\r\n',
#   b'ROBERSON\r\n',
#   b'BARTON\r\n',
#   b'TRAN\r\n',
#   b'LAMB\r\n',
#   b'HARRINGTON\r\n',
#   b'CASEY\r\n',
#   b'BOONE\r\n',
#   b'CORTEZ\r\n',
#   b'CLARKE\r\n',
#   b'MATHIS\r\n',
#   b'SINGLETON\r\n',
#   b'WILKINS\r\n',
#   b'CAIN\r\n',
#   b'BRYAN\r\n',
#   b'UNDERWOOD\r\n',
#   b'HOGAN\r\n',
#   b'MCKENZIE\r\n',
#   b'COLLIER\r\n',
#   b'LUNA\r\n',
#   b'PHELPS\r\n',
#   b'MCGUIRE\r\n',
#   b'ALLISON\r\n',
#   b'BRIDGES\r\n',
#   b'WILKERSON\r\n',
#   b'NASH\r\n',
#   b'SUMMERS\r\n',
#   b'ATKINS\r\n',
#   b'WILCOX\r\n',
#   b'PITTS\r\n',
#   b'CONLEY\r\n',
#   b'MARQUEZ\r\n',
#   b'BURNETT\r\n',
#   b'RICHARD\r\n',
#   b'COCHRAN\r\n',
#   b'CHASE\r\n',
#   b'DAVENPORT\r\n',
#   b'HOOD\r\n',
#   b'GATES\r\n',
#   b'CLAY\r\n',
#   b'AYALA\r\n',
#   b'SAWYER\r\n',
#   b'ROMAN\r\n',
#   b'VAZQUEZ\r\n',
#   b'DICKERSON\r\n',
#   b'HODGE\r\n',
#   b'ACOSTA\r\n',
#   b'FLYNN\r\n',
#   b'ESPINOZA\r\n',
#   b'NICHOLSON\r\n',
#   b'MONROE\r\n',
#   b'WOLF\r\n',
#   b'MORROW\r\n',
#   b'KIRK\r\n',
#   b'RANDALL\r\n',
#   b'ANTHONY\r\n',
#   b'WHITAKER\r\n',
#   b'OCONNOR\r\n',
#   b'SKINNER\r\n',
#   b'WARE\r\n',
#   b'MOLINA\r\n',
#   b'KIRBY\r\n',
#   b'HUFFMAN\r\n',
#   b'BRADFORD\r\n',
#   b'CHARLES\r\n',
#   b'GILMORE\r\n',
#   b'DOMINGUEZ\r\n',
#   b'ONEAL\r\n',
#   b'BRUCE\r\n',
#   b'LANG\r\n',
#   b'COMBS\r\n',
#   b'KRAMER\r\n',
#   b'HEATH\r\n',
#   b'HANCOCK\r\n',
#   b'GALLAGHER\r\n',
#   b'GAINES\r\n',
#   b'SHAFFER\r\n',
#   b'SHORT\r\n',
#   b'WIGGINS\r\n',
#   b'MATHEWS\r\n',
#   b'MCCLAIN\r\n',
#   b'FISCHER\r\n',
#   b'WALL\r\n',
#   b'SMALL\r\n',
#   b'MELTON\r\n',
#   b'HENSLEY\r\n',
#   b'BOND\r\n',
#   b'DYER\r\n',
#   b'CAMERON\r\n',
#   b'GRIMES\r\n',
#   b'CONTRERAS\r\n',
#   b'CHRISTIAN\r\n',
#   b'WYATT\r\n',
#   b'BAXTER\r\n',
#   b'SNOW\r\n',
#   b'MOSLEY\r\n',
#   b'SHEPHERD\r\n',
#   b'LARSEN\r\n',
#   b'HOOVER\r\n',
#   b'BEASLEY\r\n',
#   b'GLENN\r\n',
#   b'PETERSEN\r\n',
#   b'WHITEHEAD\r\n',
#   b'MEYERS\r\n',
#   b'KEITH\r\n',
#   b'GARRISON\r\n',
#   b'VINCENT\r\n',
#   b'SHIELDS\r\n',
#   b'HORN\r\n',
#   b'SAVAGE\r\n',
#   b'OLSEN\r\n',
#   b'SCHROEDER\r\n',
#   b'HARTMAN\r\n',
#   b'WOODARD\r\n',
#   b'MUELLER\r\n',
#   b'KEMP\r\n',
#   b'DELEON\r\n',
#   b'BOOTH\r\n',
#   b'PATEL\r\n',
#   b'CALHOUN\r\n',
#   b'WILEY\r\n',
#   b'EATON\r\n',
#   b'CLINE\r\n',
#   b'NAVARRO\r\n',
#   b'HARRELL\r\n',
#   b'LESTER\r\n',
#   b'HUMPHREY\r\n',
#   b'PARRISH\r\n',
#   b'DURAN\r\n',
#   b'HUTCHINSON\r\n',
#   b'HESS\r\n',
#   b'DORSEY\r\n',
#   b'BULLOCK\r\n',
#   b'ROBLES\r\n',
#   b'BEARD\r\n',
#   b'DALTON\r\n',
#   b'AVILA\r\n',
#   b'VANCE\r\n',
#   b'RICH\r\n',
#   b'BLACKWELL\r\n',
#   b'YORK\r\n',
#   b'JOHNS\r\n',
#   b'BLANKENSHIP\r\n',
#   b'TREVINO\r\n',
#   b'SALINAS\r\n',
#   b'CAMPOS\r\n',
#   b'PRUITT\r\n',
#   b'MOSES\r\n',
#   b'CALLAHAN\r\n',
#   b'GOLDEN\r\n',
#   b'MONTOYA\r\n',
#   b'HARDIN\r\n',
#   b'GUERRA\r\n',
#   b'MCDOWELL\r\n',
#   b'CAREY\r\n',
#   b'STAFFORD\r\n',
#   b'GALLEGOS\r\n',
#   b'HENSON\r\n',
#   b'WILKINSON\r\n',
#   b'BOOKER\r\n',
#   b'MERRITT\r\n',
#   b'MIRANDA\r\n',
#   b'ATKINSON\r\n',
#   b'ORR\r\n',
#   b'DECKER\r\n',
#   b'HOBBS\r\n',
#   b'PRESTON\r\n',
#   b'TANNER\r\n',
#   b'KNOX\r\n',
#   b'PACHECO\r\n',
#   b'STEPHENSON\r\n',
#   b'GLASS\r\n',
#   b'ROJAS\r\n',
#   b'SERRANO\r\n',
#   b'MARKS\r\n',
#   b'HICKMAN\r\n',
#   b'ENGLISH\r\n',
#   b'SWEENEY\r\n',
#   b'STRONG\r\n',
#   b'PRINCE\r\n',
#   b'MCCLURE\r\n',
#   b'CONWAY\r\n',
#   b'WALTER\r\n',
#   b'ROTH\r\n',
#   b'MAYNARD\r\n',
#   b'FARRELL\r\n',
#   b'LOWERY\r\n',
#   b'HURST\r\n',
#   b'NIXON\r\n',
#   b'WEISS\r\n',
#   b'TRUJILLO\r\n',
#   b'ELLISON\r\n',
#   b'SLOAN\r\n',
#   b'JUAREZ\r\n',
#   b'WINTERS\r\n',
#   b'MCLEAN\r\n',
#   b'RANDOLPH\r\n',
#   b'LEON\r\n',
#   b'BOYER\r\n',
#   b'VILLARREAL\r\n',
#   b'MCCALL\r\n',
#   b'GENTRY\r\n',
#   b'CARRILLO\r\n',
#   b'KENT\r\n',
#   b'AYERS\r\n',
#   b'LARA\r\n',
#   b'SHANNON\r\n',
#   b'SEXTON\r\n',
#   b'PACE\r\n',
#   b'HULL\r\n',
#   b'LEBLANC\r\n',
#   b'BROWNING\r\n',
#   b'VELASQUEZ\r\n',
#   b'LEACH\r\n',
#   b'CHANG\r\n',
#   b'HOUSE\r\n',
#   b'SELLERS\r\n',
#   b'HERRING\r\n',
#   b'NOBLE\r\n',
#   b'FOLEY\r\n',
#   b'BARTLETT\r\n',
#   b'MERCADO\r\n',
#   b'LANDRY\r\n',
#   b'DURHAM\r\n',
#   b'WALLS\r\n',
#   b'BARR\r\n',
#   b'MCKEE\r\n',
#   b'BAUER\r\n',
#   b'RIVERS\r\n',
#   b'EVERETT\r\n',
#   b'BRADSHAW\r\n',
#   b'PUGH\r\n',
#   b'VELEZ\r\n',
#   b'RUSH\r\n',
#   b'ESTES\r\n',
#   b'DODSON\r\n',
#   b'MORSE\r\n',
#   b'SHEPPARD\r\n',
#   b'WEEKS\r\n',
#   b'CAMACHO\r\n',
#   b'BEAN\r\n',
#   b'BARRON\r\n',
#   b'LIVINGSTON\r\n',
#   b'MIDDLETON\r\n',
#   b'SPEARS\r\n',
#   b'BRANCH\r\n',
#   b'BLEVINS\r\n',
#   b'CHEN\r\n',
#   b'KERR\r\n',
#   b'MCCONNELL\r\n',
#   b'HATFIELD\r\n',
#   b'HARDING\r\n',
#   b'ASHLEY\r\n',
#   b'SOLIS\r\n',
#   b'HERMAN\r\n',
#   b'FROST\r\n',
#   b'GILES\r\n',
#   b'BLACKBURN\r\n',
#   b'WILLIAM\r\n',
#   b'PENNINGTON\r\n',
#   b'WOODWARD\r\n',
#   b'FINLEY\r\n',
#   b'MCINTOSH\r\n',
#   b'KOCH\r\n',
#   b'BEST\r\n',
#   b'SOLOMON\r\n',
#   b'MCCULLOUGH\r\n',
#   b'DUDLEY\r\n',
#   b'NOLAN\r\n',
#   b'BLANCHARD\r\n',
#   b'RIVAS\r\n',
#   b'BRENNAN\r\n',
#   b'MEJIA\r\n',
#   b'KANE\r\n',
#   b'BENTON\r\n',
#   b'JOYCE\r\n',
#   b'BUCKLEY\r\n',
#   b'HALEY\r\n',
#   b'VALENTINE\r\n',
#   b'MADDOX\r\n',
#   b'RUSSO\r\n',
#   b'MCKNIGHT\r\n',
#   b'BUCK\r\n',
#   b'MOON\r\n',
#   b'MCMILLAN\r\n',
#   b'CROSBY\r\n',
#   b'BERG\r\n',
#   b'DOTSON\r\n',
#   b'MAYS\r\n',
#   b'ROACH\r\n',
#   b'CHURCH\r\n',
#   b'CHAN\r\n',
#   b'RICHMOND\r\n',
#   b'MEADOWS\r\n',
#   b'FAULKNER\r\n',
#   b'ONEILL\r\n',
#   b'KNAPP\r\n',
#   b'KLINE\r\n',
#   b'BARRY\r\n',
#   b'OCHOA\r\n',
#   b'JACOBSON\r\n',
#   b'GAY\r\n',
#   b'AVERY\r\n',
#   b'HENDRICKS\r\n',
#   b'HORNE\r\n',
#   b'SHEPARD\r\n',
#   b'HEBERT\r\n',
#   b'CHERRY\r\n',
#   b'CARDENAS\r\n',
#   b'MCINTYRE\r\n',
#   b'WHITNEY\r\n',
#   b'WALLER\r\n',
#   b'HOLMAN\r\n',
#   b'DONALDSON\r\n',
#   b'CANTU\r\n',
#   b'TERRELL\r\n',
#   b'MORIN\r\n',
#   b'GILLESPIE\r\n',
#   b'FUENTES\r\n',
#   b'TILLMAN\r\n',
#   b'SANFORD\r\n',
#   b'BENTLEY\r\n',
#   b'PECK\r\n',
#   b'KEY\r\n',
#   b'SALAS\r\n',
#   b'ROLLINS\r\n',
#   b'GAMBLE\r\n',
#   b'DICKSON\r\n',
#   b'BATTLE\r\n',
#   b'SANTANA\r\n',
#   b'CABRERA\r\n',
#   b'CERVANTES\r\n',
#   b'HOWE\r\n',
#   b'HINTON\r\n',
#   b'HURLEY\r\n',
#   b'SPENCE\r\n',
#   b'ZAMORA\r\n',
#   b'YANG\r\n',
#   b'MCNEIL\r\n',
#   b'SUAREZ\r\n',
#   b'CASE\r\n',
#   b'PETTY\r\n',
#   b'GOULD\r\n',
#   b'MCFARLAND\r\n',
#   b'SAMPSON\r\n',
#   b'CARVER\r\n',
#   b'BRAY\r\n',
#   b'ROSARIO\r\n',
#   b'MACDONALD\r\n',
#   b'STOUT\r\n',
#   b'HESTER\r\n',
#   b'MELENDEZ\r\n',
#   b'DILLON\r\n',
#   b'FARLEY\r\n',
#   b'HOPPER\r\n',
#   b'GALLOWAY\r\n',
#   b'POTTS\r\n',
#   b'BERNARD\r\n',
#   b'JOYNER\r\n',
#   b'STEIN\r\n',
#   b'AGUIRRE\r\n',
#   b'OSBORN\r\n',
#   b'MERCER\r\n',
#   b'BENDER\r\n',
#   b'FRANCO\r\n',
#   b'ROWLAND\r\n',
#   b'SYKES\r\n',
#   b'BENJAMIN\r\n',
#   b'TRAVIS\r\n',
#   b'PICKETT\r\n',
#   b'CRANE\r\n',
#   b'SEARS\r\n',
#   b'MAYO\r\n',
#   b'DUNLAP\r\n',
#   b'HAYDEN\r\n',
#   b'WILDER\r\n',
#   b'MCKAY\r\n',
#   b'COFFEY\r\n',
#   b'MCCARTY\r\n',
#   b'EWING\r\n',
#   b'COOLEY\r\n',
#   b'VAUGHAN\r\n',
#   b'BONNER\r\n',
#   b'COTTON\r\n',
#   b'HOLDER\r\n',
#   b'STARK\r\n',
#   b'FERRELL\r\n',
#   b'CANTRELL\r\n',
#   b'FULTON\r\n',
#   b'LYNN\r\n',
#   b'LOTT\r\n',
#   b'CALDERON\r\n',
#   b'ROSA\r\n',
#   b'POLLARD\r\n',
#   b'HOOPER\r\n',
#   b'BURCH\r\n',
#   b'MULLEN\r\n',
#   b'FRY\r\n',
#   b'RIDDLE\r\n',
#   b'LEVY\r\n',
#   b'DAVID\r\n',
#   b'DUKE\r\n',
#   b'ODONNELL\r\n',
#   b'GUY\r\n',
#   b'MICHAEL\r\n',
#   b'BRITT\r\n',
#   b'FREDERICK\r\n',
#   b'DAUGHERTY\r\n',
#   b'BERGER\r\n',
#   b'DILLARD\r\n',
#   b'ALSTON\r\n',
#   b'JARVIS\r\n',
#   b'FRYE\r\n',
#   b'RIGGS\r\n',
#   b'CHANEY\r\n',
#   b'ODOM\r\n',
#   b'DUFFY\r\n',
#   b'FITZPATRICK\r\n',
#   b'VALENZUELA\r\n',
#   b'MERRILL\r\n',
#   b'MAYER\r\n',
#   b'ALFORD\r\n',
#   b'MCPHERSON\r\n',
#   b'ACEVEDO\r\n',
#   b'DONOVAN\r\n',
#   b'BARRERA\r\n',
#   b'ALBERT\r\n',
#   b'COTE\r\n',
#   b'REILLY\r\n',
#   b'COMPTON\r\n',
#   b'RAYMOND\r\n',
#   b'MOONEY\r\n',
#   b'MCGOWAN\r\n',
#   b'CRAFT\r\n',
#   b'CLEVELAND\r\n',
#   b'CLEMONS\r\n',
#   b'WYNN\r\n',
#   b'NIELSEN\r\n',
#   b'BAIRD\r\n',
#   b'STANTON\r\n',
#   b'SNIDER\r\n',
#   b'ROSALES\r\n',
#   b'BRIGHT\r\n',
#   b'WITT\r\n',
#   b'STUART\r\n',
#   b'HAYS\r\n',
#   b'HOLDEN\r\n',
#   b'RUTLEDGE\r\n',
#   b'KINNEY\r\n',
#   b'CLEMENTS\r\n',
#   b'CASTANEDA\r\n',
#   b'SLATER\r\n',
#   b'HAHN\r\n',
#   b'EMERSON\r\n',
#   b'CONRAD\r\n',
#   b'BURKS\r\n',
#   b'DELANEY\r\n',
#   b'PATE\r\n',
#   b'LANCASTER\r\n',
#   b'SWEET\r\n',
#   b'JUSTICE\r\n',
#   b'TYSON\r\n',
#   b'SHARPE\r\n',
#   b'WHITFIELD\r\n',
#   b'TALLEY\r\n',
#   b'MACIAS\r\n',
#   b'IRWIN\r\n',
#   b'BURRIS\r\n',
#   b'RATLIFF\r\n',
#   b'MCCRAY\r\n',
#   b'MADDEN\r\n',
#   b'KAUFMAN\r\n',
#   b'BEACH\r\n',
#   b'GOFF\r\n',
#   b'CASH\r\n',
#   b'BOLTON\r\n',
#   b'MCFADDEN\r\n',
#   b'LEVINE\r\n',
#   b'GOOD\r\n',
#   b'BYERS\r\n',
#   b'KIRKLAND\r\n',
#   b'KIDD\r\n',
#   b'WORKMAN\r\n',
#   b'CARNEY\r\n',
#   b'DALE\r\n',
#   b'MCLEOD\r\n',
#   b'HOLCOMB\r\n',
#   b'ENGLAND\r\n',
#   b'FINCH\r\n',
#   b'HEAD\r\n',
#   b'BURT\r\n',
#   b'HENDRIX\r\n',
#   b'SOSA\r\n',
#   b'HANEY\r\n',
#   b'FRANKS\r\n',
#   b'SARGENT\r\n',
#   b'NIEVES\r\n',
#   b'DOWNS\r\n',
#   b'RASMUSSEN\r\n',
#   b'BIRD\r\n',
#   b'HEWITT\r\n',
#   b'LINDSAY\r\n',
#   b'LE\r\n',
#   b'FOREMAN\r\n',
#   b'VALENCIA\r\n',
#   b'ONEIL\r\n',
#   b'DELACRUZ\r\n',
#   b'VINSON\r\n',
#   b'DEJESUS\r\n',
#   b'HYDE\r\n',
#   b'FORBES\r\n',
#   b'GILLIAM\r\n',
#   b'GUTHRIE\r\n',
#   b'WOOTEN\r\n',
#   b'HUBER\r\n',
#   b'BARLOW\r\n',
#   b'BOYLE\r\n',
#   b'MCMAHON\r\n',
#   b'BUCKNER\r\n',
#   b'ROCHA\r\n',
#   b'PUCKETT\r\n',
#   b'LANGLEY\r\n',
#   b'KNOWLES\r\n',
#   b'COOKE\r\n',
#   b'VELAZQUEZ\r\n',
#   b'WHITLEY\r\n',
#   b'NOEL\r\n',
#   b'VANG\r\n',
#   ...]]

# %%
stoplist_mod = []
for list in stopw_list:
    
    for i in range(len(list)):
        
        list[i] = repr(list[i])
        
        list[i] = list[i].replace("b", '')
        list[i] = list[i].replace("\r\n", '')
        list[i] = list[i].replace("'", '')
        final = list[i].split('|', 1)[0]
        
        stoplist_mod.append(final)

# %%
for i in range (len(stoplist_mod)):
    
    stoplist_mod[i] = stoplist_mod[i].replace("\\r\\n", "").lower()

# %% [markdown]
# AN IMRPOVISED STOPWORD LIST THAT CONTAINS THE STOPWORDS FROM THE GIVEN FILE
#
# AS WELL AS NLTK'S STANDARD STOPWORD LIST, TO DO BETTER CLEANING

# %%
stoplist_mod
# Out:
# ['ernst',
#  'young',
#  'deloitte',
#  'touche',
#  'kpmg',
#  'pricewaterhousecoopers',
#  'pricewaterhouse',
#  'coopers',
#  'afghani  ',
#  'ariary ',
#  'baht ',
#  'balboa ',
#  'birr ',
#  'bolivar ',
#  'boliviano  ',
#  'cedi ',
#  'colon  ',
#  'c\\xd3rdoba  ',
#  'dalasi ',
#  'denar ',
#  'dinar ',
#  'dirham  ',
#  'dobra ',
#  'dong ',
#  'dram ',
#  'escudo  ',
#  'euro  ',
#  'florin ',
#  'forint ',
#  'gourde ',
#  'guarani ',
#  'gulden ',
#  'hryvnia  ',
#  'kina ',
#  'kip ',
#  'konvertibilna marka  ',
#  'koruna  ',
#  'krona ',
#  'krone ',
#  'kroon ',
#  'kuna ',
#  'kwacha ',
#  'kwanza ',
#  'kyat ',
#  'lari ',
#  'lats ',
#  'lek ',
#  'lempira ',
#  'leone ',
#  'leu ',
#  'lev ',
#  'lilangeni  ',
#  'lira ',
#  'litas ',
#  'loti ',
#  'manat ',
#  'metical ',
#  'naira ',
#  'nakfa ',
#  'new lira ',
#  'new sheqel  ',
#  'ngultrum  ',
#  'nuevo sol ',
#  'ouguiya  ',
#  'pataca ',
#  'peso  ',
#  'pound  ',
#  'pula  ',
#  'quetzal ',
#  'rand ',
#  'real  ',
#  'renminbi  ',
#  'rial ',
#  'riel ',
#  'ringgit ',
#  'riyal ',
#  'ruble ',
#  'rufiyaa ',
#  'rupee  ',
#  'rupee  ',
#  'rupiah  ',
#  'shilling  ',
#  'som ',
#  'somoni  ',
#  'special drawing rights  ',
#  'taka ',
#  'tala ',
#  'tenge ',
#  'tugrik  ',
#  'vatu ',
#  'won  ',
#  'yen ',
#  'zloty ',
#  'hundred  ',
#  'thousand',
#  'million',
#  'billion',
#  'trillion',
#  'date  ',
#  'annual',
#  'annually',
#  'annum',
#  'year',
#  'yearly',
#  'quarter',
#  'quarterly',
#  'qtr',
#  'month',
#  'monthly',
#  'week',
#  'weekly',
#  'day',
#  'daily',
#  'january  ',
#  'february',
#  'march',
#  'april',
#  'may',
#  'june',
#  'july',
#  'august',
#  'september',
#  'october',
#  'november',
#  'december',
#  'jan',
#  'feb',
#  'mar',
#  'apr',
#  'may',
#  'jun',
#  'jul',
#  'aug',
#  'sep',
#  'sept',
#  'oct',
#  'nov',
#  'dec',
#  'monday',
#  'tuesday',
#  'wednesday',
#  'thursday',
#  'friday',
#  'saturday',
#  'sunday',
#  'one  ',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'eleven',
#  'twelve',
#  'thirteen',
#  'fourteen',
#  'fifteen',
#  'sixteen',
#  'seventeen',
#  'eighteen',
#  'nineteen',
#  'twenty',
#  'thirty',
#  'forty',
#  'fifty',
#  'sixty',
#  'seventy',
#  'eighty',
#  'ninety',
#  'first',
#  'second',
#  'third',
#  'fourth',
#  'fifth',
#  'sixth',
#  'seventh',
#  'eighth',
#  'ninth',
#  'tenth',
#  'i  ',
#  'ii',
#  'iii',
#  'iv',
#  'v',
#  'vi',
#  'vii',
#  'viii',
#  'ix',
#  'x',
#  'xi',
#  'xii',
#  'xiii',
#  'xiv',
#  'xv',
#  'xvi',
#  'xvii',
#  'xviii',
#  'xix',
#  'xx',
#  'about',
#  'above',
#  'after',
#  'again',
#  'all',
#  'am',
#  'among',
#  'an',
#  'and',
#  'any',
#  'are',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'has',
#  'have',
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'if',
#  'in',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'me',
#  'more',
#  'most',
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'same',
#  'she',
#  'should',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  'we',
#  'were',
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'with',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'a',
#  '"as"',
#  'ale',
#  'aout',
#  'aove',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  '"aint"',
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'are',
#  '"arent"',
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'availale',
#  'away',
#  'awfully',
#  '',
#  'e',
#  'ecame',
#  'ecause',
#  'ecome',
#  'ecomes',
#  'ecoming',
#  'een',
#  'efore',
#  'eforehand',
#  'ehind',
#  'eing',
#  'elieve',
#  'elow',
#  'eside',
#  'esides',
#  'est',
#  'etter',
#  'etween',
#  'eyond',
#  'oth',
#  'rief',
#  'ut',
#  'y',
#  'c',
#  '"cmon"',
#  '"cs"',
#  'came',
#  'can',
#  '"cant"',
#  'cannot',
#  'cant',
#  'cause',
#  'causes',
#  'certain',
#  'certainly',
#  'changes',
#  'clearly',
#  'co',
#  'com',
#  'come',
#  'comes',
#  'concerning',
#  'consequently',
#  'consider',
#  'considering',
#  'contain',
#  'containing',
#  'contains',
#  'corresponding',
#  'could',
#  '"couldnt"',
#  'course',
#  'currently',
#  'd',
#  'definitely',
#  'descried',
#  'despite',
#  'did',
#  '"didnt"',
#  'different',
#  'do',
#  'does',
#  '"doesnt"',
#  'doing',
#  '"dont"',
#  'done',
#  'down',
#  'downwards',
#  'during',
#  'e',
#  'each',
#  'edu',
#  'eg',
#  'eight',
#  'either',
#  'else',
#  'elsewhere',
#  'enough',
#  'entirely',
#  'especially',
#  'et',
#  'etc',
#  'even',
#  'ever',
#  'every',
#  'everyody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'exactly',
#  'example',
#  'except',
#  'f',
#  'far',
#  'few',
#  'fifth',
#  'first',
#  'five',
#  'followed',
#  'following',
#  'follows',
#  'for',
#  'former',
#  'formerly',
#  'forth',
#  'four',
#  'from',
#  'further',
#  'furthermore',
#  'g',
#  'get',
#  'gets',
#  'getting',
#  'given',
#  'gives',
#  'go',
#  'goes',
#  'going',
#  'gone',
#  'got',
#  'gotten',
#  'greetings',
#  'h',
#  'had',
#  '"hadnt"',
#  'happens',
#  'hardly',
#  'has',
#  '"hasnt"',
#  'have',
#  '"havent"',
#  'having',
#  'he',
#  '"hes"',
#  'hello',
#  'help',
#  'hence',
#  'her',
#  'here',
#  '"heres"',
#  'hereafter',
#  'herey',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'hi',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hopefully',
#  'how',
#  'howeit',
#  'however',
#  'i',
#  '"id"',
#  '"ill"',
#  '"im"',
#  '"ive"',
#  'ie',
#  'if',
#  'ignored',
#  'immediate',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'indicate',
#  'indicated',
#  'indicates',
#  'inner',
#  'insofar',
#  'instead',
#  'into',
#  'inward',
#  'is',
#  '"isnt"',
#  'it',
#  '"itd"',
#  '"itll"',
#  '"its"',
#  'its',
#  'itself',
#  'j',
#  'just',
#  'k',
#  'keep',
#  'keeps',
#  'kept',
#  'know',
#  'knows',
#  'known',
#  'l',
#  'last',
#  'lately',
#  'later',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'lest',
#  'let',
#  '"lets"',
#  'like',
#  'liked',
#  'likely',
#  'little',
#  'look',
#  'looking',
#  'looks',
#  'ltd',
#  'm',
#  'mainly',
#  'many',
#  'may',
#  'maye',
#  'me',
#  'mean',
#  'meanwhile',
#  'merely',
#  'might',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'much',
#  'must',
#  'my',
#  'myself',
#  'n',
#  'name',
#  'namely',
#  'nd',
#  'near',
#  'nearly',
#  'necessary',
#  'need',
#  'needs',
#  'neither',
#  'never',
#  'nevertheless',
#  'new',
#  'next',
#  'nine',
#  'no',
#  'noody',
#  'non',
#  'none',
#  'noone',
#  'nor',
#  'normally',
#  'not',
#  'nothing',
#  'novel',
#  'now',
#  'nowhere',
#  'o',
#  'oviously',
#  'of',
#  'off',
#  'often',
#  'oh',
#  'ok',
#  'okay',
#  'old',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'outside',
#  'over',
#  'overall',
#  'own',
#  'p',
#  'particular',
#  'particularly',
#  'per',
#  'perhaps',
#  'placed',
#  'please',
#  'plus',
#  'possile',
#  'presumaly',
#  'proaly',
#  'provides',
#  'q',
#  'que',
#  'quite',
#  'qv',
#  'r',
#  'rather',
#  'rd',
#  're',
#  'really',
#  'reasonaly',
#  'regarding',
#  'regardless',
#  'regards',
#  'relatively',
#  'respectively',
#  'right',
#  's',
#  'said',
#  'same',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'second',
#  'secondly',
#  'see',
#  'seeing',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'seen',
#  'self',
#  'selves',
#  'sensile',
#  'sent',
#  'serious',
#  'seriously',
#  'seven',
#  'several',
#  'shall',
#  'she',
#  'should',
#  '"shouldnt"',
#  'since',
#  'six',
#  'so',
#  'some',
#  'someody',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhat',
#  'somewhere',
#  'soon',
#  'sorry',
#  'specified',
#  'specify',
#  'specifying',
#  'still',
#  'su',
#  'such',
#  'sup',
#  'sure',
#  't',
#  '"ts"',
#  'take',
#  'taken',
#  'tell',
#  'tends',
#  'th',
#  'than',
#  'thank',
#  'thanks',
#  'thanx',
#  'that',
#  '"thats"',
#  'thats',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  '"theres"',
#  'thereafter',
#  'therey',
#  'therefore',
#  'therein',
#  'theres',
#  'thereupon',
#  'these',
#  'they',
#  '"theyd"',
#  '"theyll"',
#  '"theyre"',
#  '"theyve"',
#  'think',
#  'third',
#  'this',
#  'thorough',
#  'thoroughly',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'took',
#  'toward',
#  'towards',
#  'tried',
#  'tries',
#  'truly',
#  'try',
#  'trying',
#  'twice',
#  'two',
#  'u',
#  'un',
#  'under',
#  'unfortunately',
#  'unless',
#  'unlikely',
#  'until',
#  'unto',
#  'up',
#  'upon',
#  'us',
#  'use',
#  'used',
#  'useful',
#  'uses',
#  'using',
#  'usually',
#  'uucp',
#  'v',
#  'value',
#  'various',
#  'very',
#  'via',
#  'viz',
#  'vs',
#  'w',
#  'want',
#  'wants',
#  'was',
#  '"wasnt"',
#  'way',
#  'we',
#  '"wed"',
#  '"well"',
#  '"were"',
#  '"weve"',
#  'welcome',
#  'well',
#  'went',
#  'were',
#  '"werent"',
#  'what',
#  '"whats"',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  '"wheres"',
#  'whereafter',
#  'whereas',
#  'wherey',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  '"whos"',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'willing',
#  'wish',
#  'with',
#  'within',
#  'without',
#  '"wont"',
#  'wonder',
#  'would',
#  'would',
#  '"wouldnt"',
#  'x',
#  'y',
#  'yes',
#  'yet',
#  'you',
#  '"youd"',
#  '"youll"',
#  '"youre"',
#  '"youve"',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'z',
#  'zero',
#  'united  ',
#  'state',
#  'north',
#  'south',
#  'east',
#  'northeast',
#  'northwest',
#  'southeast',
#  'southwest',
#  'west',
#  'ocean',
#  'sea',
#  'lake',
#  'river',
#  'creek',
#  'gulf',
#  'mountain',
#  'street',
#  'boulevard',
#  'blvd',
#  'parkway',
#  'city',
#  'county',
#  'country',
#  'pacific',
#  'atlantic',
#  'indian',
#  'mediterranean',
#  'commonwealth',
#  'america',
#  'american',
#  'york  ',
#  'chicago',
#  'las',
#  'vegas',
#  'los',
#  'angeles',
#  'milwaukee',
#  'sunnyvale',
#  'fremont',
#  'cincinnati',
#  'philadelphia',
#  'miami',
#  'dallas',
#  'fort',
#  'boston',
#  'houston',
#  'washington',
#  'atlanta',
#  'detroit',
#  'san',
#  'fransico',
#  'phoenix',
#  'seattle',
#  'diego',
#  'minneapolis',
#  'memphis',
#  'denver',
#  'st',
#  'louis',
#  'pittsburgh',
#  'manhattan',
#  'hollywood',
#  'columbus',
#  'indianapolis',
#  'mumbai',
#  'karachi',
#  'ontario',
#  'toronto',
#  'cambridge',
#  'delhi',
#  'sao',
#  'paulo',
#  'shanghai',
#  'moscow',
#  'seoul',
#  'istanbul',
#  'tokyo',
#  'jakarta',
#  'beijing',
#  'london',
#  'luxembourg',
#  'singapore',
#  'republic  ',
#  'china',
#  'india',
#  'indonesia',
#  'brazil',
#  'brazilian',
#  'pakistan',
#  'bangladesh',
#  'russia',
#  'nigeria',
#  'nova',
#  'scotia',
#  'japan',
#  'malaysia',
#  'mexico',
#  'mexican',
#  'philippines',
#  'vietnam',
#  'germany',
#  'france',
#  'korea',
#  'spain',
#  'argentina',
#  ...]

# %% [markdown]
# SCRAPING AND CREATING A LIST OF PARAGRAPHS

# %%
import urllib.request

article_list = []

from bs4 import BeautifulSoup as bs 

for i in range(len(df)):
    
    url = df['URL'][i]
    
    try:
        
        html = urllib.request.urlopen(url)
        
        
        html_parse = bs(html, 'html.parser')
        
        para = html_parse.find_all('div',{'class':'td-post-content tagdiv-type'}, 'p')
        
        y = ""
        
        for x in para:
            
            y += x.text
            
        
        y = y.replace('\n','')
        article_list.append(y)
        
    except:
        
        article_list.append('')
        
        print(f"HTTP error at index{i} URL:{df['URL'][i]}")

# %%
for i in range(len(article_list)):
    
    article_list[i] = article_list[i].lower()

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words1 = stop_words + stoplist_mod

# %%
from nltk.stem import  WordNetLemmatizer

lem = WordNetLemmatizer()
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Sohan
# [nltk_data]     M\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def process(paragraph):    # The main cleaning function of the paragraph
                           # to get rid of all unecessary words and punctuations.
        
    word = nltk.word_tokenize(paragraph)
    filtered_para = [lem.lemmatize(w) for w in word if not w.lower() in stop_words1]
    filtered_para_mod = [filt for filt in filtered_para if filt.isalpha()]
    return filtered_para_mod

# %%
print(process(article_list[1])) # Just trying out the main process fuction
# Out:
# ['human', 'mind', 'fascination', 'carrying', 'potential', 'tinkering', 'nature', 'pixie', 'dust', 'intelligence', 'creating', 'solving', 'mystery', 'wonder', 'admiration', 'matter', 'captivating', 'human', 'mind', 'appalled', 'hunger', 'maybe', 'beyond', 'unravel', 'limitation', 'maybe', 'pure', 'greed', 'human', 'stopped', 'evolving', 'intelligence', 'make', 'call', 'supremacy', 'evolve', 'opposed', 'challenge', 'human', 'mind', 'capability', 'making', 'question', 'importance', 'artificial', 'intelligence', 'revolution', 'havoc', 'concept', 'making', 'machine', 'work', 'granting', 'machine', 'idea', 'making', 'machine', 'work', 'human', 'people', 'believe', 'thing', 'making', 'thing', 'work', 'task', 'mention', 'surpass', 'human', 'skill', 'fact', 'greatest', 'chess', 'kasparov', 'defeated', 'chess', 'game', 'machine', 'top', 'skilled', 'human', 'lost', 'mere', 'machine', 'created', 'defeated', 'betterment', 'skill', 'granted', 'supremacy', 'machine', 'tool', 'equipment', 'helped', 'unskilled', 'mind', 'intelligence', 'creates', 'skilled', 'work', 'perfection', 'precision', 'initially', 'time', 'passed', 'human', 'drawn', 'puzzle', 'lot', 'changed', 'human', 'research', 'deeper', 'deeper', 'result', 'machine', 'evolved', 'present', 'machine', 'growing', 'develops', 'improves', 'become', 'part', 'industrial', 'revolution', 'industry', 'laborious', 'work', 'care', 'human', 'replaced', 'machine', 'naturally', 'evolution', 'machine', 'precision', 'mass', 'productivity', 'quality', 'control', 'time', 'efficiency', 'factor', 'made', 'better', 'choice', 'choice', 'led', 'fear', 'fear', 'future', 'future', 'maybe', 'machine', 'evolved', 'human', 'employee', 'leading', 'unemployment', 'population', 'increase', 'world', 'became', 'tech', 'threat', 'labor', 'market', 'oppose', 'threat', 'adapting', 'technology', 'make', 'million', 'people', 'lose', 'job', 'lead', 'mass', 'unemployment', 'machine', 'surpass', 'human', 'creation', 'creator', 'matter', 'fearful', 'future', 'reality', 'scary', 'truth', 'present', 'reality', 'hold', 'unlock', 'level', 'human', 'evolution', 'technology', 'growing', 'time', 'technology', 'idea', 'today', 'idea', 'implemented', 'working', 'carried', 'nobody', 'stop', 'advancement', 'growth', 'artificial', 'intelligence', 'wave', 'flowing', 'present', 'generation', 'generation', 'learn', 'learn', 'swim', 'flow', 'avoid', 'job', 'replaced', 'machine', 'evolves', 'challenging', 'human', 'mind', 'skill', 'present', 'covid', 'situation', 'contactless', 'cashier', 'robot', 'delivering', 'package', 'usual', 'routine', 'task', 'job', 'secretary', 'scheduler', 'risk', 'manufacturing', 'unit', 'agriculture', 'food', 'service', 'retail', 'transportation', 'logistic', 'hospitality', 'part', 'automation', 'estimation', 'job', 'including', 'manufacturing', 'lost', 'robot', 'robotics', 'printing', 'genetics', 'make', 'architect', 'medical', 'doc', 'composer', 'feel', 'threatened', 'technology', 'making', 'question', 'job', 'machine', 'replacing', 'job', 'creating', 'job', 'economic', 'growth', 'innovation', 'investment', 'job', 'generated', 'newly', 'enhanced', 'job', 'create', 'benefit', 'amplify', 'creativity', 'strategy', 'entrepreneurial', 'skill', 'catch', 'skill', 'creating', 'time', 'job', 'destroying', 'skill', 'count', 'surged', 'job', 'opportunity', 'opportunity', 'senior', 'data', 'scientist', 'mobile', 'application', 'developer', 'seo', 'specialist', 'job', 'job', 'qualification', 'skill', 'acquire', 'skill', 'expensive', 'task', 'future', 'generation', 'able', 'struggle', 'faced', 'present', 'generation', 'vulnerability', 'skill', 'gap', 'unemployment', 'youth', 'crushed', 'advancement', 'becomes', 'inevitable', 'remains', 'choice', 'adapt', 'learn', 'equip', 'company', 'work', 'build', 'workplace', 'collaborate', 'government', 'educator', 'organization', 'work', 'bring', 'policy', 'understand', 'technology', 'impact', 'faster', 'providing', 'employee', 'security', 'economic', 'business', 'planning', 'made', 'con ...

# %% [markdown]
# NOTE: THE WORD LIST AFTER TOKENIZING EACH PARAGRAPH IS ALWAYS CLEANED BEFORE DETERMINING
#
# ANY PARAMETER.
#
# SO THE WORD LENGTH OF EACH PARAGRAPH IS DIFFERENT THAN THE ORIGINAL LENGTH

# %%
#These are helper functions to determine the number of positive / negative words

def plus(sent):
    
    countpos = 0    
    
    
    for e in sent:
        
        if e in positive:
            countpos +=1
            
        else:
            countpos+=0
            
    
    return countpos



def minus(sent):
    
    countneg = 0    
    
    for e in sent:
        
        if e in negative:
            countneg +=1
            
        else:
            countneg+=0
            
   
    
    return countneg

# %%
#Functions to obtain the positive score , negative score, Polarity score
#and subjectivity score

def obtainpos(para):
    
    matrixplus = []

    
    
    
    sents = nltk.sent_tokenize(para)
    for sent in sents:
        filtered_words = process(sent)
        
        pos_score = plus(filtered_words)
        matrixplus.append(pos_score)
        
        
    return sum(matrixplus)

def obtainneg(para):
    
    matrixminus = []
    
    
    sents = nltk.sent_tokenize(para)
    for sent in sents:
        filtered_words = process(sent)
        
        neg_score = minus(filtered_words)
        matrixminus.append(neg_score)
        
        
    return sum(matrixminus)


def polarity(para):       #Polarity Score: This is the score that determines if a given text is positive or negative in nature. It is calculated by using the formula: Polarity Score = (Positive Score – Negative Score)/ ((Positive Score + Negative Score) + 0.000001)

    
    return (obtainpos(para)-obtainneg(para))/(obtainpos(para) + obtainneg(para)+0.000001)

def subjectivity(para):
    
    words = process(para)
    
    return(obtainpos(para)+obtainneg(para))/(len(words)+0.000001)

# %%
import re
pronounReg = re.compile(r'\b(i|we|my|ours|(?-i:us))\b', re.I)

# %%
import pyphen
dic = pyphen.Pyphen(lang= 'en')


def numb_syllables(para):          #From What is understood from the task, this function
                                   #returns the list of syllable number per word in a paragraph 
    syllable_list = []
    
    words = process(para)
    for word in words:
        count = 0

        
        list_ = dic.inserted(word).split('-')
        if('es' in list_):
            count+=1
            
        elif('ed' in list_):
            count+=1
            
            
        syllable_list.append(len(list_) - count)
    return(syllable_list)
            
            
        


def num_complexword(para):    #Complex words are words in the text that contain more than two syllables.
    
    
    compword = []
    
    words_mod = process(para)
    
    for word in words_mod:
        
        if(len(dic.inserted(word).split('-'))> 2):
            
            compword.append(word)
            
    return(len(compword))


def percentage_complex(para):
    
   
    words_mod = process(para)
    
    return(num_complexword(para)/len(words_mod))*100


def wordpersent(para):     #Average Number of Words Per Sentence = the total number of words / the total number of sentences

    
    words = 0
    
    sents = nltk.sent_tokenize(para)
    
    for sent in sents:
        wds_mod = process(sent)
        
        words += len(wds_mod)
        
    return words/len(sents)


def avg_sent_len(para):      #Average Sentence Length = the number of words / the number of sentences

    sents = nltk.sent_tokenize(para)
    words = process(para)
    
    return (len(words)/len(sents))


def fog_index(para):         #Fog Index = 0.4 * (Average Sentence Length + Percentage of Complex words)
    
    return 0.4*(avg_sent_len(para)+ percentage_complex(para))

def pronoun_count(para):     #Count the number of personal pronouns in a paragraph
    pronoun_list = pronounReg.findall(para)
    
    return(pronoun_list)

def avg_word_length(para):    #Average Word Length is calculated by the formula:
                             #Sum of the total number of characters in each word/Total number of words

    lentotal = 0
    
    words = process(para)
    for word in words:
        
        lentotal += len(word)
        
    return (lentotal/len(words))

def word_count(para):
    
    words = process(para)
    return len(words)

# %%
dict_list = []

# %%
for i in range(len(article_list)):    #Creation of a list of dictionaries that has all the column names as 
                                    
                                      #as KEYS and the return values of the above functions defined as VALUES
    try:
        dictionary = {}
        
        
        dictionary['POSITIVE SCORE'] = obtainpos(article_list[i])
        dictionary['NEGATIVE SCORE'] = obtainneg(article_list[i])

        dictionary['POLARITY SCORE'] = polarity(article_list[i])
        dictionary['SUBJECTIVITY SCORE'] = subjectivity(article_list[i])
        dictionary['AVG SENTENCE LENGTH'] = avg_sent_len(article_list[i])
        dictionary['PERCENTAGE OF COMPLEX WORDS'] = percentage_complex(article_list[i])
        dictionary['FOG INDEX'] = fog_index(article_list[i])
        dictionary['AVG NUMBER OF WORDS PER SENTENCE'] = wordpersent(article_list[i])
        dictionary['COMPLEX WORD COUNT'] = num_complexword(article_list[i])
        dictionary['WORD COUNT'] = word_count(article_list[i])
        dictionary['SYLLABLE PER WORD'] = numb_syllables(article_list[i])
        dictionary['PERSONAL PRONOUNS'] = pronoun_count(article_list[i])
        dictionary['AVG WORD LENGTH'] = avg_word_length(article_list[i])
        
        
        dict_list.append(dictionary)
        
        
    except:
        
        dictionary = {}
        
        dictionary['POSITIVE SCORE'] = "This para is empty as URL showed error"
        
        dict_list.append(dictionary)

# %%
print(dict_list[103])
# Out:
# {'POSITIVE SCORE': 15, 'NEGATIVE SCORE': 53, 'POLARITY SCORE': -0.5588235211937718, 'SUBJECTIVITY SCORE': 0.15560640696657574, 'AVG SENTENCE LENGTH': 11.205128205128204, 'PERCENTAGE OF COMPLEX WORDS': 23.79862700228833, 'FOG INDEX': 14.001502082966613, 'AVG NUMBER OF WORDS PER SENTENCE': 11.205128205128204, 'COMPLEX WORD COUNT': 104, 'WORD COUNT': 437, 'SYLLABLE PER WORD': [1, 5, 3, 5, 2, 2, 3, 2, 1, 2, 2, 2, 3, 1, 2, 2, 1, 1, 2, 2, 3, 2, 2, 1, 2, 1, 2, 2, 2, 1, 1, 3, 2, 2, 2, 3, 2, 4, 3, 1, 2, 1, 1, 2, 2, 3, 3, 1, 1, 4, 2, 2, 1, 3, 1, 2, 1, 2, 1, 1, 3, 2, 2, 2, 2, 2, 3, 2, 1, 4, 1, 2, 2, 4, 2, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 3, 2, 2, 3, 5, 2, 2, 1, 1, 2, 3, 2, 3, 2, 2, 1, 2, 2, 2, 2, 2, 2, 3, 2, 1, 2, 1, 2, 2, 2, 3, 3, 1, 1, 1, 2, 2, 1, 1, 2, 2, 2, 2, 1, 1, 2, 2, 3, 2, 2, 2, 2, 3, 1, 1, 3, 2, 2, 2, 2, 1, 1, 1, 1, 3, 3, 4, 1, 1, 3, 1, 2, 1, 1, 1, 1, 1, 1, 1, 3, 1, 2, 2, 1, 2, 3, 3, 3, 2, 1, 1, 3, 1, 2, 1, 3, 3, 4, 1, 3, 3, 3, 1, 1, 2, 1, 1, 1, 4, 2, 1, 2, 1, 2, 2, 1, 2, 4, 2, 2, 2, 2, 1, 1, 1, 2, 1, 1, 1, 1, 1, 3, 3, 1, 1, 2, 2, 1, 1, 3, 1, 1, 2, 3, 1, 1, 2, 2, 1, 1, 1, 3, 1, 1, 3, 1, 1, 1, 2, 1, 1, 1, 3, 2, 2, 1, 2, 1, 1, 1, 2, 4, 1, 1, 2, 2, 1, 4, 1, 1, 1, 2, 2, 3, 1, 1, 2, 1, 1, 4, 1, 2, 1, 1, 3, 2, 1, 3, 2, 1, 2, 2, 2, 3, 2, 3, 1, 2, 1, 1, 2, 1, 2, 2, 2, 1, 2, 2, 2, 1, 4, 3, 2, 2, 2, 1, 4, 2, 1, 2, 1, 1, 2, 2, 3, 5, 1, 3, 2, 1, 1, 3, 2, 3, 2, 2, 3, 1, 3, 1, 1, 1, 1, 1, 2, 1, 1, 3, 2, 3, 2, 1, 4, 2, 2, 2, 2, 1, 4, 1, 1, 1, 3, 2, 3, 1, 1, 1, 2, 2, 1, 3, 2, 1, 1, 2, 1, 1, 3, 1, 3, 1, 2, 3, 2, 1, 1, 3, 1, 2, 3, 1, 2, 1, 3, 1, 2, 2, 2, 4, 3, 2, 2, 2, 3, 1, 2, 1, 2, 1, 2, 1, 3, 4, 1, 1, 2, 3, 1, 3, 1, 2, 4, 3, 4, 2, 1, 3, 2, 2, 3, 2, 3, 2, 2, 2, 2, 2, 2, 1], 'PERSONAL PRONOUNS': [], 'AVG WORD LENGTH': 6.853546910755148}

# %%
len(dict_list)
# Out:
# 114

# %%
outp_data = pd.read_excel('./Output Data Structure.xlsx')
df2 = pd.DataFrame(outp_data)

# %%
df2
# Out:
#      URL_ID                                                URL  \
# 0        37  https://insights.blackcoffer.com/ai-in-healthc...
# 1        38  https://insights.blackcoffer.com/what-if-the-c...
# 2        39  https://insights.blackcoffer.com/what-jobs-wil...
# 3        40  https://insights.blackcoffer.com/will-machine-...
# 4        41  https://insights.blackcoffer.com/will-ai-repla...
# ..      ...                                                ...
# 109     146  https://insights.blackcoffer.com/blockchain-fo...
# 110     147  https://insights.blackcoffer.com/the-future-of...
# 111     148  https://insights.blackcoffer.com/big-data-anal...
# 112     149  https://insights.blackcoffer.com/business-anal...
# 113     150  https://insights.blackcoffer.com/challenges-an...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0               NaN             NaN             NaN                 NaN
# 1               NaN             NaN             NaN                 NaN
# 2               NaN             NaN             NaN                 NaN
# 3               NaN             NaN             NaN                 NaN
# 4               NaN             NaN             NaN                 NaN
# ..              ...             ...             ...                 ...
# 109             NaN             NaN             NaN                 NaN
# 110             NaN             NaN             NaN                 NaN
# 111             NaN             NaN             NaN                 NaN
# 112             NaN             NaN             NaN                 NaN
# 113             NaN             NaN             NaN                 NaN
#
#      AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                    NaN                          NaN        NaN
# 1                    NaN                          NaN        NaN
# 2                    NaN                          NaN        NaN
# 3                    NaN                          NaN        NaN
# 4                    NaN                          NaN        NaN
# ..                   ...                          ...        ...
# 109                  NaN                          NaN        NaN
# 110                  NaN                          NaN        NaN
# 111                  NaN                          NaN        NaN
# 112                  NaN                          NaN        NaN
# 113                  NaN                          NaN        NaN
#
#      AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                                 NaN                 NaN         NaN
# 1                                 NaN                 NaN         NaN
# 2                                 NaN                 NaN         NaN
# 3                                 NaN                 NaN         NaN
# 4                                 NaN                 NaN         NaN
# ..                                ...                 ...         ...
# 109                               NaN                 NaN         NaN
# 110                               NaN                 NaN         NaN
# 111                               NaN                 NaN         NaN
# 112                               NaN                 NaN         NaN
# 113                               NaN                 NaN         NaN
#
#      SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                  NaN                NaN              NaN
# 1                  NaN                NaN              NaN
# 2                  NaN                NaN              NaN
# 3                  NaN                NaN              NaN
# 4                  NaN                NaN              NaN
# ..                 ...                ...              ...
# 109                NaN                NaN              NaN
# 110                NaN                NaN              NaN
# 111                NaN                NaN              NaN
# 112                NaN                NaN              NaN
# 113                NaN                NaN              NaN
#
# [114 rows x 15 columns]

# %% [markdown]
# CONVERTING THE DICTIONARY LIST TO A PANDAS DATAFRAME

# %%
df3 = pd.DataFrame.from_dict(dict_list)

# %%
df3
# Out:
#                              POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  \
# 0                                        72            31.0        0.398058
# 1                                        73            36.0        0.339450
# 2                                        68            40.0        0.259259
# 3                                        73            27.0        0.460000
# 4    This para is empty as URL showed error             NaN             NaN
# ..                                      ...             ...             ...
# 109                                      20            26.0       -0.130435
# 110                                      36            11.0        0.531915
# 111                                      44            48.0       -0.043478
# 112                                      43             5.0        0.791667
# 113                                      42            38.0        0.050000
#
#      SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  \
# 0              0.115342            16.849057                    32.250840
# 1              0.204503             7.955224                    27.204503
# 2              0.137405            11.731343                    30.788804
# 3              0.161551             7.935897                    24.878837
# 4                   NaN                  NaN                          NaN
# ..                  ...                  ...                          ...
# 109            0.122016            10.189189                    27.586207
# 110            0.074367            14.044444                    28.322785
# 111            0.164580             9.163934                    29.338104
# 112            0.139130            19.166667                    41.159420
# 113            0.167364             7.709677                    26.987448
#
#      FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  \
# 0    19.639959                         16.849057               288.0
# 1    14.063891                          7.955224               145.0
# 2    17.008059                         11.731343               242.0
# 3    13.125894                          7.935897               154.0
# 4          NaN                               NaN                 NaN
# ..         ...                               ...                 ...
# 109  15.110158                         10.189189               104.0
# 110  16.946892                         14.044444               179.0
# 111  15.400815                          9.163934               164.0
# 112  24.130435                         19.166667               142.0
# 113  13.878850                          7.709677               129.0
#
#      WORD COUNT                                  SYLLABLE PER WORD  \
# 0         893.0  [4, 1, 1, 2, 1, 3, 2, 1, 2, 2, 3, 1, 1, 1, 2, ...
# 1         533.0  [2, 1, 4, 3, 3, 2, 1, 2, 1, 4, 3, 2, 2, 2, 4, ...
# 2         786.0  [4, 2, 1, 3, 2, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, ...
# 3         619.0  [1, 1, 4, 1, 4, 4, 3, 2, 4, 3, 1, 1, 2, 2, 1, ...
# 4           NaN                                                NaN
# ..          ...                                                ...
# 109       377.0  [4, 3, 2, 1, 3, 1, 1, 3, 1, 1, 1, 1, 3, 1, 2, ...
# 110       632.0  [3, 3, 2, 1, 2, 3, 3, 1, 4, 4, 3, 1, 1, 3, 1, ...
# 111       559.0  [2, 3, 2, 2, 3, 1, 1, 3, 2, 1, 3, 4, 4, 2, 2, ...
# 112       345.0  [3, 4, 3, 2, 4, 2, 3, 2, 1, 1, 2, 3, 1, 1, 3, ...
# 113       478.0  [1, 2, 2, 2, 1, 1, 2, 3, 1, 1, 1, 1, 1, 1, 1, ...
#
#                                      PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                                                 [us]         7.409854
# 1                          [we, us, us, i, us, we, we]         6.911820
# 2                                         [we, us, us]         7.540712
# 3    [us, we, us, we, we, we, we, we, we, we, us, w...         6.933764
# 4                                                  NaN              NaN
# ..                                                 ...              ...
# 109                     [my, i, i, my, i, i, i, i, us]         7.458886
# 110  [us, us, us, us, us, us, us, us, us, us, us, u...         7.031646
# 111                                           [my, we]         6.969589
# 112                                                 []         7.979710
# 113                    [i, we, we, we, we, we, my, we]         7.018828
#
# [114 rows x 13 columns]

# %% [markdown]
# AS THE DATAFRAME DOES NOT HAVE 'URL_ID' AND 'URL' ,
#
# THOSE FEATURES HAVE BEEN ADDED USING THE df2 DATAFRAME
#
# DEFINED BY THE 'OUTPUT DATA STRUCTURE.XLSX' FILE

# %%
df3.insert(0, 'URL', df2['URL'])

# %%
df3.insert(0, 'URL_ID', df2['URL_ID'])

# %% [markdown]
# FINALLY CONVERT THE FINAL DATAFRAME TO excel FILE

# %%
df3.to_excel('Output Data Structure_1.xlsx')

# %%
# !pip install ipynb-py-convert
# Out:
# Collecting ipynb-py-convert
#   Downloading ipynb-py-convert-0.4.6.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: ipynb-py-convert
#   Building wheel for ipynb-py-convert (setup.py): started
#   Building wheel for ipynb-py-convert (setup.py): finished with status 'done'
#   Created wheel for ipynb-py-convert: filename=ipynb_py_convert-0.4.6-py3-none-any.whl size=4640 sha256=c33310449d7a5ca83cb7ff7032ddccbd30dd722581de59df2883a18153f8190c
#   Stored in directory: c:\users\sohan m\appdata\local\pip\cache\wheels\69\a2\b7\2816fda86a647adbe8c4e7b7f4cc72cdc37720ad11b1611af5
# Successfully built ipynb-py-convert
# Installing collected packages: ipynb-py-convert
# Successfully installed ipynb-py-convert-0.4.6

# %%
import ipynb_py_convert as ip

# %%
ip Taskfile.py Taskfile.ipynb
# Out:
#   Input In [3]
#     ip Taskfile.py Taskfile.ipynb
#        ^
# SyntaxError: invalid syntax
